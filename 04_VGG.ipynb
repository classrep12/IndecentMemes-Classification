# %% [markdown]
# # **# Facebook Hateful Meme Dataset, Downsampling, Preprocessing and EDA.**

# %% [markdown]
# # Starting data file:
# # /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/train.jsonl
# # Preprocessing steps: cleaning, downsampling, text & image normalization

# %%
# Cell 1: Install & import
# !pip install kagglehub --quiet

import os
import shutil
import zipfile
import random
from pathlib import Path
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from tqdm import tqdm

import kagglehub

# %%
# Cell 2: Download dataset with kagglehub
# This will download and return local path where files are stored in the Colab VM
dataset_ref = "parthplc/facebook-hateful-meme-dataset"
path = kagglehub.dataset_download(dataset_ref)
print("Path to dataset files:", path)

# List files in that path to see CSVs and images folder (adjust if path differs)
for root, dirs, files in os.walk(path):
    # print top-level only for brevity
    print(root)
    print("  subdirs:", dirs)
    print("  files (sample):", files[:20])
    break
# Out:
# Using Colab cache for faster access to the 'facebook-hateful-meme-dataset' dataset.
# Path to dataset files: /kaggle/input/facebook-hateful-meme-dataset
# /kaggle/input/facebook-hateful-meme-dataset
#   subdirs: ['data']
#   files (sample): []

# %%
#Helper cell before cell 3
import os

for root, dirs, files in os.walk(path):
    for name in files:
        if name.lower().endswith(('.csv', '.json', '.zip', '.tsv', '.xlsx')):
            print(os.path.join(root, name))

# %%
import os

# List all files directly under the downloaded path
print("Files and folders inside:", path)
print(os.listdir(path))
# Out:
# Files and folders inside: /kaggle/input/facebook-hateful-meme-dataset
# ['data']

# %%
import os

data_path = os.path.join(path, "data")
print("Files inside data folder:", os.listdir(data_path))

# Also show full paths (in case there are nested subfolders)
for root, dirs, files in os.walk(data_path):
    for name in files:
        print(os.path.join(root, name))
# Out:
# Streaming output truncated to the last 5000 lines.
# /kaggle/input/facebook-hateful-meme-dataset/data/img/06375.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/64510.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/62031.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/71593.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/37450.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/31429.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/89675.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/38752.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/06893.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/95402.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/09738.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/43216.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/07314.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/79316.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/04768.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/65207.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/72431.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/26803.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/50163.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/92370.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/59321.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/27308.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/61840.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/17948.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/64520.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/10749.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/21948.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/53062.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/82637.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/19635.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/79581.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/78459.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/56438.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/70935.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/42380.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/17354.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/53108.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/68201.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/70142.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/57132.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/29483.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/32965.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/96180.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/20348.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/74509.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/45198.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/41782.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/01842.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/61928.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/93568.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/07265.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/36179.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/54837.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/34298.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/54983.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/71492.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/51387.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/82945.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/05329.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/26170.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/15907.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/31892.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/13958.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/80765.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/98105.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/94518.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/83527.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/48710.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/43679.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/98057.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/60539.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/49867.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/12839.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/79286.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/68951.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/87543.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/26735.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/23576.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/30675.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/24570.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/64059.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/09641.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/69487.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/19502.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/43658.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/61278.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/89206.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/02165.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/70254.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/17425.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/32150.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/56387.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/01439.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/30481.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/41032.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/61032.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/03271.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/10793.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/18367.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/82794.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/53817.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/26340.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/03751.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/98235.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/26189.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/93685.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/13652.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/62981.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/61492.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/48916.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/02389.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/05781.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/25841.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/63412.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/83497.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/27069.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/36098.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/89571.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/29357.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/87016.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/95264.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/46208.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/10453.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/86417.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/19384.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/67915.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/87024.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/62017.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/96305.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/63905.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/96510.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/73615.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/20654.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/49372.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/21647.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/23419.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/71320.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/67194.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/42160.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/65980.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/87169.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/38765.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/96423.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/62948.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/10385.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/59732.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/72964.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/75923.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/62435.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/32981.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/45730.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/64390.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/40651.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/48970.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/87620.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/69708.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/60234.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/31208.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/96421.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/54376.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/87203.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/38076.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/57913.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/82097.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/82743.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/36128.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/50643.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/76810.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/36845.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/34652.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/67082.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/21957.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/75430.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/60147.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/46352.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/59062.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/39860.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/76305.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/05872.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/23415.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/64157.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/10839.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/68159.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/97320.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/04153.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/70541.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/72469.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/48120.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/46150.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/74031.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/94815.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/12657.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/69052.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/76320.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/80397.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/69415.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/93786.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/15649.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/36184.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/80379.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/37620.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/98573.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/42091.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/58190.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/39741.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/50784.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/97524.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/73561.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/89521.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/89634.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/87693.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/74536.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/51964.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/56207.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/72984.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/26087.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/19345.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/03254.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/50486.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/51763.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/17280.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/23058.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/06597.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/83719.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/49128.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/60571.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/17869.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/89475.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/56791.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/29547.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/75321.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/73981.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/02971.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/61085.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/25149.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/76894.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/41728.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/16029.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/51968.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/04762.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/09426.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/79823.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/26137.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/67593.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/50934.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/07594.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/50124.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/43952.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/82704.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/89726.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/78493.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/47183.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/58642.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/51249.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/78035.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/78610.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/95062.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/50361.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/89723.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/81203.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/43092.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/07653.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/73128.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/78923.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/98426.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/43095.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/61480.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/73965.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/43859.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/34092.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/37498.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/61054.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/12509.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/14097.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/39061.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/48015.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/04621.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/09251.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/70582.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/02815.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/70285.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/93718.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/51697.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/48173.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/93861.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/14685.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/75216.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/43207.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/17058.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/21593.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/70562.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/02945.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/35971.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/47320.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/92167.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/36897.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/06541.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/57094.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/68751.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/47385.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/92146.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/84103.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/72418.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/68540.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/98357.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/42153.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/02143.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/87905.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/80567.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/73164.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/47189.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/29075.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/40735.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/90643.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/69842.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/95024.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/10395.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/46817.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/65940.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/61597.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/83704.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/60183.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/75290.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/20437.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/37146.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/87539.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/08415.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/39607.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/69125.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/51726.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/45780.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/06125.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/18074.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/85970.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/19837.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/16837.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/51469.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/63501.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/39816.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/25109.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/09432.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/42039.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/96182.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/29054.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/72430.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/20791.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/20598.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/62135.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/56712.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/71680.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/24501.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/71524.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/03248.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/89615.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/73082.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/45396.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/74298.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/80926.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/79405.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/83916.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/64870.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/26531.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/91836.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/07392.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/07258.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/40837.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/02385.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/79615.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/01765.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/52496.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/38574.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/08476.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/64925.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/19647.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/96123.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/92670.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/50237.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/05749.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/32081.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/29678.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/69480.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/56287.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/53968.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/96541.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/27059.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/93152.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/28045.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/32867.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/01845.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/24738.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/45817.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/37145.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/10976.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/06987.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/32459.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/41806.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/45289.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/85714.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/35249.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/84523.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/70628.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/17892.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/06875.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/26784.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/63201.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/49836.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/81940.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/97103.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/27518.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/48927.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/48517.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/56189.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/65201.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/59370.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/63182.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/19643.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/38741.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/35784.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/90632.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/64820.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/06319.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/92375.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/34275.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/83921.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/19726.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/03971.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/08691.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/78564.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/20861.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/58974.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/09467.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/54083.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/28935.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/80714.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/48309.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/18650.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/42173.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/57831.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/84179.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/94013.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/70643.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/61742.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/17682.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/83246.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/83701.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/38629.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/48617.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/29351.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/57034.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/65432.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/72145.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/76034.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/23957.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/05362.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/87695.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/82916.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/79140.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/28964.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/05978.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/09238.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/01658.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/12907.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/87634.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/34021.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/82104.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/14523.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/37845.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/83402.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/49136.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/63827.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/85271.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/74386.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/91853.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/35640.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/90126.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/28043.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/34698.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/70183.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/46359.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/62541.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/05986.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/20371.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/56413.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/97845.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/85371.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/74126.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/90673.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/80513.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/10372.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/10675.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/37502.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/53976.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/14078.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/64128.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/47605.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/48192.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/34106.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/45281.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/28157.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/82946.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/94783.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/80123.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/19240.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/40896.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/64391.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/87049.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/84172.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/72591.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/53204.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/02139.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/75698.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/45987.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/19268.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/83091.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/86354.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/73049.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/97610.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/15948.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/73816.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/28659.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/69307.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/86372.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/02483.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/83152.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/86075.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/73152.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/79610.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/02568.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/53419.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/43570.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/14859.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/27915.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/93076.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/86013.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/78251.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/35182.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/79853.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/04125.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/52790.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/54601.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/51943.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/63105.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/81509.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/65843.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/78914.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/78450.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/28396.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/85192.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/24586.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/43519.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/78124.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/97035.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/38724.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/79834.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/16478.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/31256.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/49170.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/86907.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/92405.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/28613.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/31280.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/91367.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/16395.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/84295.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/46178.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/79516.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/10357.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/17268.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/10732.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/83510.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/30591.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/71509.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/82593.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/94026.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/15942.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/67059.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/27163.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/40297.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/39148.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/31059.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/72048.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/09723.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/90625.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/14389.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/84970.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/60549.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/71430.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/40681.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/10652.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/57932.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/41268.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/70315.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/02351.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/14726.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/01736.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/31782.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/38654.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/46920.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/67951.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/92407.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/08134.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/36109.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/28954.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/53948.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/89430.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/25643.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/04397.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/31794.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/62485.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/40597.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/74906.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/69134.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/96172.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/02763.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/02358.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/09642.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/15078.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/06927.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/52316.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/30792.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/05138.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/64051.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/06127.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/24876.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/06479.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/37084.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/73105.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/03854.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/01359.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/80945.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/19075.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/10582.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/87039.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/10362.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/91756.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/97426.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/64297.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/97601.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/25097.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/46978.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/90247.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/80316.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/47239.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/68379.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/37091.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/02519.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/06352.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/32189.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/54816.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/05462.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/06291.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/67521.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/58246.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/26439.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/74385.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/81630.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/43517.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/39547.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/47612.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/43279.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/65342.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/45189.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/79352.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/63097.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/71568.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/76405.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/40865.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/53096.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/45283.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/10952.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/56739.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/20643.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/51480.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/98412.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/50684.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/12430.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/74261.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/94237.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/73204.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/94850.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/65024.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/02863.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/04782.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/34620.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/40862.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/70634.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/13520.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/16892.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/35709.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/86391.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/37814.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/56432.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/31468.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/61859.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/67384.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/59148.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/32704.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/05436.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/75294.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/05926.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/13506.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/93671.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/48123.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/41023.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/94581.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/68713.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/47518.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/41250.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/26579.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/57823.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/80251.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/63417.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/36240.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/70368.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/23690.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/14856.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/17652.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/46218.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/51972.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/10936.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/72301.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/18274.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/43906.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/52106.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/28495.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/38490.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/20869.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/69410.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/28976.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/59327.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/50348.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/69357.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/90657.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/68530.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/84907.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/92068.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/08563.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/04637.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/30862.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/79168.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/02849.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/83024.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/75614.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/06374.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/94350.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/75231.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/52910.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/43956.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/30986.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/81536.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/20745.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/46832.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/85097.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/01269.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/79461.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/89741.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/75832.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/07159.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/78642.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/21730.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/04791.png
# ...
# /kaggle/input/facebook-hateful-meme-dataset/data/img/31029.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/47391.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/09387.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/86205.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/24905.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/87564.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/25093.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/78406.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/32514.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/04689.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/95371.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/72386.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/98736.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/46823.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/02356.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/34671.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/31586.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/82165.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/05984.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/03296.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/63589.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/51348.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/93280.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/93126.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/67892.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/78541.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/91730.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/94357.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/36521.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/49328.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/25874.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/46058.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/26043.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/34629.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/54210.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/07824.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/12648.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/36058.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/15290.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/78015.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/52139.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/15803.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/08693.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/07452.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/45930.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/54917.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/15647.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/43571.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/70914.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/96824.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/16702.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/73926.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/42783.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/72598.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/61380.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/39640.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/79824.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/26307.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/31625.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/06435.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/95071.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/94675.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/36107.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/34618.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/56709.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/89056.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/16437.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/24687.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/02514.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/03268.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/69380.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/56873.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/75319.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/51046.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/54639.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/09827.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/76253.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/68753.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/80451.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/73421.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/62509.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/75846.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/29164.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/12374.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/08523.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/47836.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/64593.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/62019.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/02965.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/17253.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/24857.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/14570.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/62301.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/56124.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/34076.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/47591.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/61754.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/98145.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/20786.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/31847.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/16207.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/98530.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/71308.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/52719.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/37294.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/62307.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/73914.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/57013.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/07385.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/40257.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/46205.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/08567.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/56378.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/72839.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/35680.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/70934.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/10476.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/96258.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/71390.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/10725.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/81962.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/08317.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/05948.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/83976.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/62418.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/48279.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/98157.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/28579.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/74956.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/89423.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/58326.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/45923.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/51682.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/43217.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/91082.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/04379.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/51460.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/20134.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/25498.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/07345.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/79346.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/45263.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/42691.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/90753.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/30756.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/91763.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/34756.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/96450.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/42319.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/93841.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/59726.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/91863.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/42391.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/23459.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/62308.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/25634.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/49017.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/84926.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/07238.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/92846.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/96340.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/39107.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/15067.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/60427.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/41830.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/14830.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/13098.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/93275.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/70318.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/89142.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/10835.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/87390.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/36420.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/65328.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/50142.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/96845.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/58019.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/39862.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/51683.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/39206.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/98751.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/16089.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/58217.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/23851.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/69042.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/56723.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/01627.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/13074.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/74890.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/26598.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/68039.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/96420.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/23048.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/98421.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/23794.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/65078.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/80179.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/47693.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/94650.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/82651.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/81759.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/43096.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/27156.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/65234.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/50682.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/78260.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/28793.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/85741.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/93027.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/90461.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/94358.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/62198.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/90236.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/47615.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/47530.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/62758.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/83429.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/54691.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/56891.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/60981.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/84361.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/15846.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/54108.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/76980.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/58370.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/41506.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/61793.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/53274.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/32015.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/04563.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/28096.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/69720.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/61453.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/59287.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/80246.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/49067.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/81096.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/54610.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/92158.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/86314.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/49021.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/30124.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/34508.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/87401.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/76250.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/32971.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/39214.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/46197.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/98637.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/04356.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/65931.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/60132.png
# /kaggle/input/facebook-hateful-meme-dataset/data/img/36054.png

# %%
import os

data_path = os.path.join(path, "data")

# Look only for json/jsonl/csv files (ignore images)
meta_files = []
for root, dirs, files in os.walk(data_path):
    for name in files:
        if name.lower().endswith(('.json', '.jsonl', '.csv', '.tsv')):
            meta_files.append(os.path.join(root, name))

print("Metadata files found:")
for f in meta_files:
    print(f)
# Out:
# Metadata files found:
# /kaggle/input/facebook-hateful-meme-dataset/data/dev.jsonl
# /kaggle/input/facebook-hateful-meme-dataset/data/test.jsonl
# /kaggle/input/facebook-hateful-meme-dataset/data/train.jsonl

# %%
#data/
 #├── img/             ← meme images
 #├── train.jsonl      ← training metadata
 #├── dev.jsonl        ← validation metadata
 #└── test.jsonl       ← test metadata

# %%
#Load the training data
import pandas as pd

train_path = os.path.join(path, "data", "train.jsonl")

# Load JSON lines file
df = pd.read_json(train_path, lines=True)
print("✅ Loaded train.jsonl successfully")
print("Shape:", df.shape)
print("\nColumns:", df.columns.tolist())

# Display first few rows
df.head()
# Out:
# ✅ Loaded train.jsonl successfully
# Shape: (8500, 4)
#
# Columns: ['id', 'img', 'label', 'text']
#       id            img  label  \
# 0  42953  img/42953.png      0
# 1  23058  img/23058.png      0
# 2  13894  img/13894.png      0
# 3  37408  img/37408.png      0
# 4  82403  img/82403.png      0
#
#                                                 text
# 0   its their character not their color that matters
# 1  don't be afraid to love again everyone is not ...
# 2                           putting bows on your pet
# 3  i love everything and everybody! except for sq...
# 4  everybody loves chocolate chip cookies, even h...

# %%
#Check Class Distribution
print("Class distribution:")
print(df['label'].value_counts())

# Percentage split
print("\nPercentage split:")
print((df['label'].value_counts(normalize=True) * 100).round(2))
# Out:
# Class distribution:
# label
# 0    5450
# 1    3050
# Name: count, dtype: int64
#
# Percentage split:
# label
# 0    64.12
# 1    35.88
# Name: proportion, dtype: float64

# %% [markdown]
#  Dataset size: 8,500 memes
#
#  Columns: id, img, label, text
#
#  Class distribution:
#
# Non-hateful (0): 64%
#
# Hateful (1): 36%
#
# Images stored under: data/img/

# %% [markdown]
# ## **DownSampling of the Data**

# %%
#Downsampling of the dataset
from sklearn.model_selection import train_test_split
import os
from pathlib import Path
import shutil
from tqdm import tqdm

# Parameters
downsample_n = 4000          # change to another size later if needed
random_state = 42

# Calculate fraction
frac = downsample_n / len(df)

# Stratified sampling based on 'label'
idx = df.index.values
idx_sample, _ = train_test_split(
    idx,
    train_size=frac,
    stratify=df['label'],
    random_state=random_state
)

df_sample = df.loc[idx_sample].reset_index(drop=True)

print("Downsampled shape:", df_sample.shape)
print("Label distribution in sample:")
print(df_sample['label'].value_counts(normalize=True).round(3) * 100)

# Create output folders
output_dir = Path("hateful_memes_downsampled")
images_out = output_dir / "images"
os.makedirs(images_out, exist_ok=True)

# Paths
image_base_dir = os.path.join(path, "data")

# Copy images
print("\nCopying selected images...")
for img_file in tqdm(df_sample['img']):
    src = os.path.join(image_base_dir, img_file)
    dst = os.path.join(images_out, os.path.basename(img_file))
    shutil.copy(src, dst)

# Save downsampled CSV
df_sample.to_csv(output_dir / "downsampled_metadata.csv", index=False)
print("\n✅ Downsample complete.")
print("Saved to:", output_dir / "downsampled_metadata.csv")
print("Images saved in:", images_out)
# Out:
# Downsampled shape: (4000, 4)
# Label distribution in sample:
# label
# 0    64.1
# 1    35.9
# Name: proportion, dtype: float64
#
# Copying selected images...
# 100%|██████████| 4000/4000 [00:53<00:00, 74.47it/s]
# ✅ Downsample complete.
# Saved to: hateful_memes_downsampled/downsampled_metadata.csv
# Images saved in: hateful_memes_downsampled/images

# %%
len(os.listdir("hateful_memes_downsampled/images"))
# Out:
# 4000

# %% [markdown]
# # **Preprocessing of the Data**

# %%
# ---------- CELL A: imports + helpers ----------
# !pip install tqdm --quiet

import os, re, string, shutil, json
from pathlib import Path
from tqdm import tqdm
import pandas as pd
import numpy as np
import cv2
from sklearn.model_selection import train_test_split

# reproducibility
RND = 42

# helper: robust text cleaner (removes emojis, urls, punctuation, numbers)
def clean_text_advanced(text):
    text = "" if pd.isna(text) else str(text)
    # lowercase
    text = text.lower()
    # remove urls
    text = re.sub(r"http\S+|www\S+|https\S+", "", text, flags=re.IGNORECASE)
    # remove emojis (simple approach)
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags
                               "]+", flags=re.UNICODE)
    text = emoji_pattern.sub(r"", text)
    # remove digits
    text = re.sub(r"\d+", "", text)
    # remove punctuation
    text = re.sub(f"[{re.escape(string.punctuation)}]", "", text)
    # normalize whitespace
    text = re.sub(r"\s+", " ", text).strip()
    return text

# %%
# ---------- CELL B: ensure df_sample available ----------
# If df_sample already exists in environment (from previous steps), this is no-op.
if 'df_sample' in globals():
    print("df_sample already present with shape:", df_sample.shape)
else:
    # try reloading train.jsonl and re-create sample (safe fallback)
    dataset_jsonl = Path(path) / "data" / "train.jsonl"
    if dataset_jsonl.exists():
        print("Loading full train.jsonl from:", dataset_jsonl)
        df_full = pd.read_json(dataset_jsonl, lines=True)
        print("Full df shape:", df_full.shape)
        # if you want to re-create the same 4000-sample downsample, use same seed
        downsample_n = 4000
        idx = df_full.index.values
        frac = downsample_n / len(df_full)
        idx_sample, _ = train_test_split(idx, train_size=frac, stratify=df_full['label'], random_state=RND)
        df_sample = df_full.loc[idx_sample].reset_index(drop=True)
        print("Recreated df_sample shape:", df_sample.shape)
    else:
        raise FileNotFoundError("df_sample not found and train.jsonl not present at expected location. Make sure you have path and dataset downloaded.")
# Out:
# df_sample already present with shape: (4000, 4)

# %%
# ---------- CELL C: sanity checks ----------
output_dir = Path("hateful_memes_downsampled")
images_dir = output_dir / "images"                     # images you copied earlier
processed_dir = output_dir / "processed_images"       # later output

print("df_sample shape:", df_sample.shape)
print("\nColumns:", df_sample.columns.tolist())

# Ensure label ints
df_sample['label'] = df_sample['label'].astype(int)

# Check duplicates (image filename + text)
dup_img = df_sample.duplicated(subset=['img']).sum()
dup_text = df_sample.duplicated(subset=['text']).sum()
print(f"\nDuplicate image filenames: {dup_img}")
print(f"Duplicate text entries: {dup_text}")

# Check missing files in images_dir
missing_files = []
for img in df_sample['img']:
    fname = os.path.basename(img)
    if not (images_dir / fname).exists():
        missing_files.append(fname)
print(f"\nMissing image files in {images_dir}: {len(missing_files)}")
if len(missing_files)>0:
    print("First 20 missing:", missing_files[:20])

# Quick drop of any rows that point to missing images (if any)
if len(missing_files) > 0:
    before = len(df_sample)
    df_sample = df_sample[~df_sample['img'].apply(lambda x: os.path.basename(x) in set(missing_files))].reset_index(drop=True)
    print(f"Dropped {before - len(df_sample)} rows due to missing images. New shape: {df_sample.shape}")

# Drop exact duplicates if present (very rare)
before = len(df_sample)
df_sample.drop_duplicates(subset=['img','text'], inplace=True)
print("Dropped exact duplicates:", before - len(df_sample))
# Out:
# df_sample shape: (4000, 4)
#
# Columns: ['id', 'img', 'label', 'text']
#
# Duplicate image filenames: 0
# Duplicate text entries: 389
#
# Missing image files in hateful_memes_downsampled/images: 0
# Dropped exact duplicates: 0

# %%
# ---------- CELL D: text cleaning & derived features ----------
# Apply the advanced cleaning function
tqdm.pandas(desc="Cleaning text")
df_sample['clean_text'] = df_sample['text'].progress_apply(clean_text_advanced)

# Derived features helpful for EDA
df_sample['text_length_chars'] = df_sample['clean_text'].apply(len)
df_sample['text_num_words'] = df_sample['clean_text'].apply(lambda x: len(x.split()) if x else 0)

# Quick stats
print("After cleaning: sample shape:", df_sample.shape)
print("\nText length (chars) — descriptive stats:")
print(df_sample['text_length_chars'].describe().round(2))
print("\nText num words — descriptive stats:")
print(df_sample['text_num_words'].describe().round(2))
# Out:
# Cleaning text: 100%|██████████| 4000/4000 [00:00<00:00, 17059.79it/s]
# After cleaning: sample shape: (4000, 7)
#
# Text length (chars) — descriptive stats:
# count    4000.00
# mean       60.11
# std        36.18
# min         4.00
# 25%        36.00
# 50%        52.00
# 75%        75.00
# max       427.00
# Name: text_length_chars, dtype: float64
#
# Text num words — descriptive stats:
# count    4000.00
# mean       11.58
# std         6.80
# min         1.00
# 25%         7.00
# 50%        10.00
# 75%        15.00
# max        68.00
# Name: text_num_words, dtype: float64

# %%
# ---------- CELL E: image preprocessing (resize + normalize) ----------
# Settings
target_size = (224, 224)
os.makedirs(processed_dir, exist_ok=True)

corrupted = []
copied = 0

for idx, row in tqdm(df_sample.iterrows(), total=len(df_sample), desc="Process images"):
    img_rel = row['img']
    img_name = os.path.basename(img_rel)
    src_path = images_dir / img_name
    dst_path = processed_dir / img_name

    try:
        img = cv2.imread(str(src_path))
        if img is None:
            corrupted.append(img_name)
            continue

        # If image channels are 1 or 4 handle them
        # convert grayscale to BGR if needed
        if len(img.shape) == 2:
            img = cv2.cvtColor(img, cv2.COLOR_GRAY2BGR)
        # drop alpha channel if present
        if img.shape[2] == 4:
            img = cv2.cvtColor(img, cv2.COLOR_BGRA2BGR)

        # resize
        img_resized = cv2.resize(img, target_size, interpolation=cv2.INTER_AREA)

        # normalize (0-255 saving still as uint8; later model pipelines typically scale to 0-1)
        cv2.imwrite(str(dst_path), img_resized)
        copied += 1
    except Exception as e:
        corrupted.append(img_name)

print(f"\nImages processed: {copied}; Corrupted/unreadable: {len(corrupted)}")
if len(corrupted)>0:
    print("First 20 corrupted:", corrupted[:20])
    # drop corrupted rows from df_sample
    before = len(df_sample)
    df_sample = df_sample[~df_sample['img'].apply(lambda x: os.path.basename(x) in set(corrupted))].reset_index(drop=True)
    print(f"Dropped {before - len(df_sample)} rows with corrupted images. New shape: {df_sample.shape}")
# Out:
# Process images: 100%|██████████| 4000/4000 [02:40<00:00, 24.86it/s]
# Images processed: 4000; Corrupted/unreadable: 0

# %%
# ---------- CELL F: save cleaned metadata + zip processed images ----------
clean_meta_path = output_dir / "cleaned_metadata_final.csv"
df_sample.to_csv(clean_meta_path, index=False)
print("Saved cleaned metadata to:", clean_meta_path)

# Zip processed images (optional, may take some time and disk)
zip_out = output_dir / "processed_images.zip"
if zip_out.exists():
    print("Zip already exists:", zip_out)
else:
    print("Creating zip (this may take a while)...")
    shutil.make_archive(str(zip_out).replace('.zip',''), 'zip', processed_dir)
    print("Created zip:", zip_out)

# Quick checks
print("\nFinal cleaned dataset shape:", df_sample.shape)
print("Processed image count:", len(list(processed_dir.glob("*.*"))))
# Out:
# Saved cleaned metadata to: hateful_memes_downsampled/cleaned_metadata_final.csv
# Creating zip (this may take a while)...
# Created zip: hateful_memes_downsampled/processed_images.zip
#
# Final cleaned dataset shape: (4000, 7)
# Processed image count: 4000

# %%
# ---------- CELL G: create stratified train/val/test splits ----------
train_val, test_df = train_test_split(df_sample, test_size=0.10, stratify=df_sample['label'], random_state=RND)
train_df, val_df = train_test_split(train_val, test_size=0.1111111, stratify=train_val['label'], random_state=RND)
# note: 0.1111111 of train_val => ~10% overall val (since 0.9 * 0.111... = 0.1)

print("Train shape:", train_df.shape)
print("Val shape:", val_df.shape)
print("Test shape:", test_df.shape)

# Save
train_df.to_csv(output_dir / "train_cleaned.csv", index=False)
val_df.to_csv(output_dir / "val_cleaned.csv", index=False)
test_df.to_csv(output_dir / "test_cleaned.csv", index=False)
print("Saved splits to:", output_dir)
# Out:
# Train shape: (3200, 7)
# Val shape: (400, 7)
# Test shape: (400, 7)
# Saved splits to: hateful_memes_downsampled

# %% [markdown]
# Here we are doing binary classification (Hateful vs Non-Hateful).That is why we are using Stratified sampling because it ensures:
#
# 1. Each split represents both types of memes fairly,
#
# 2. Our model learns from both classes, and
#
# 3. Evaluation metrics reflect the true behavior.
#
# That’s why we chose stratify=df['label'] for both:
#
# Downsampling step, and
#
# Train/validation/test split step.

# %%
# ---------- CELL H: quick EDA checks ----------
print("Overall class distribution (final):")
print(df_sample['label'].value_counts(), "\n")
print("Percentages:")
print((df_sample['label'].value_counts(normalize=True) * 100).round(2))

# Text length distributions
print("\nText length (words) mean / median:")
print(df_sample['text_num_words'].mean(), df_sample['text_num_words'].median())

# Example rows
display(df_sample.sample(6))
# Out:
# Overall class distribution (final):
# label
# 0    2565
# 1    1435
# Name: count, dtype: int64
#
# Percentages:
# label
# 0    64.12
# 1    35.88
# Name: proportion, dtype: float64
#
# Text length (words) mean / median:
# 11.576 10.0
#          id            img  label  \
# 555   57826  img/57826.png      1
# 3491  75321  img/75321.png      1
# 527    9265  img/09265.png      0
# 3925  36092  img/36092.png      0
# 2989   1389  img/01389.png      0
# 70    41063  img/41063.png      1
#
#                                                    text  \
# 555   if this is what they call pride.. then i don't...
# 3491  cannibal tribe from indonesia will take muslim...
# 527   take advantage of u.n. and foreign aid-funded ...
# 3925                      who is it and what do they do
# 2989  confession-every sunday around brunch time i t...
# 70    when the oven is full so you start putting jew...
#
#                                              clean_text  text_length_chars  \
# 555   if this is what they call pride then i dont wa...                 74
# 3491  cannibal tribe from indonesia will take muslim...                 69
# 527   take advantage of un and foreign aidfunded hou...                 81
# 3925                      who is it and what do they do                 29
# 2989  confessionevery sunday around brunch time i ta...                103
# 70    when the oven is full so you start putting jew...                 65
#
#       text_num_words
# 555               16
# 3491              11
# 527               14
# 3925               8
# 2989              19
# 70                14

# %% [markdown]
# # **EDA (Exploratory Data Analysis) of the Data**

# %%
# ---------- CELL 1: IMPORTS & LOAD CLEANED DATA ----------

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud, STOPWORDS
import cv2
import numpy as np
import random
from PIL import Image
from pathlib import Path

# Load cleaned dataset (from preprocessing step)
df = pd.read_csv("hateful_memes_downsampled/cleaned_metadata_final.csv")

print("✅ Dataset loaded successfully.")
print("Shape:", df.shape)
print("\nColumns:", df.columns.tolist())
print("\nSample rows:")
display(df.sample(5))
# Out:
# ✅ Dataset loaded successfully.
# Shape: (4000, 7)
#
# Columns: ['id', 'img', 'label', 'text', 'clean_text', 'text_length_chars', 'text_num_words']
#
# Sample rows:
#          id            img  label  \
# 1117  37809  img/37809.png      0
# 2843  53140  img/53140.png      1
# 2597  73518  img/73518.png      1
# 2044  72486  img/72486.png      0
# 727   85096  img/85096.png      1
#
#                                                    text  \
# 1117                     now that's what i call koality
# 2843  me respect women no, i don't believe bush did ...
# 2597  north korean operatives infiltrating the "stor...
# 2044                         put'n the "ham" in mohamed
# 727                                  remember no faggot
#
#                                              clean_text  text_length_chars  \
# 1117                      now thats what i call koality                 29
# 2843  me respect women no i dont believe bush did it...                 59
# 2597  north korean operatives infiltrating the storm...                 92
# 2044                            putn the ham in mohamed                 23
# 727                                  remember no faggot                 18
#
#       text_num_words
# 1117               6
# 2843              13
# 2597              15
# 2044               5
# 727                3

# %%
# ---------- CELL 2: BASIC INFO ----------

print("Dataset Info:\n")
print(df.info())
print("\n\nMissing Values per Column:")
print(df.isnull().sum())

print("\n\nLabel Distribution:")
print(df['label'].value_counts())

print("\nPercentage Split:")
print((df['label'].value_counts(normalize=True) * 100).round(2))
# Out:
# Dataset Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 4000 non-null   int64
#  1   img                4000 non-null   object
#  2   label              4000 non-null   int64
#  3   text               4000 non-null   object
#  4   clean_text         4000 non-null   object
#  5   text_length_chars  4000 non-null   int64
#  6   text_num_words     4000 non-null   int64
# dtypes: int64(4), object(3)
# memory usage: 218.9+ KB
# None
#
#
# Missing Values per Column:
# id                   0
# img                  0
# label                0
# text                 0
# clean_text           0
# text_length_chars    0
# text_num_words       0
# dtype: int64
#
#
# Label Distribution:
# label
# 0    2565
# 1    1435
# Name: count, dtype: int64
#
# Percentage Split:
# label
# 0    64.12
# 1    35.88
# Name: proportion, dtype: float64

# %%
# ---------- CELL 3: CLASS DISTRIBUTION PLOT ----------
plt.figure(figsize=(6,4))
sns.countplot(x='label', data=df, palette='coolwarm')
plt.title("Class Distribution of Memes", fontsize=14)
plt.xlabel("Label (0 = Non-Hateful, 1 = Hateful)")
plt.ylabel("Count")
plt.show()
# Out:
# /tmp/ipython-input-97431609.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='label', data=df, palette='coolwarm')

# %% [markdown]
# The bar chart displays the number of hateful (label = 1) and non-hateful (label = 0) memes in the dataset. It reveals that approximately 64 % of the samples are non-hateful and 36 % are hateful, resulting in a moderately imbalanced dataset.
#
# Observations:
#
# * The higher number of non-hateful memes means models may naturally learn to favor the majority class unless corrective measures are taken.
#
# * Despite the imbalance not being extreme, it can still bias predictions toward “non-hateful” outputs.
#
# Implications:
#
# * Stratified sampling (as you already used) ensures this ratio is preserved in train, validation, and test splits.
#
# * During model training, techniques like class-weighted loss functions or oversampling of the minority class can help mitigate bias.
#
# Key takeaway:
# * The dataset is moderately imbalanced (roughly 64 : 36). Awareness of this imbalance is essential for fair model evaluation and to prevent the classifier from under-detecting hateful content.

# %%
# ---------- CELL 4: TEXT LENGTH ANALYSIS ----------

plt.figure(figsize=(7,5))
sns.histplot(df['text_num_words'], bins=30, kde=True, color='teal')
plt.title("Distribution of Text Length (in Words)", fontsize=14)
plt.xlabel("Number of Words")
plt.ylabel("Frequency")
plt.show()

# Compare text length per class
plt.figure(figsize=(7,5))
sns.boxplot(x='label', y='text_num_words', data=df, palette='Set2')
plt.title("Text Length Distribution per Class", fontsize=14)
plt.xlabel("Label (0 = Non-Hateful, 1 = Hateful)")
plt.ylabel("Number of Words")
plt.show()
# Out:
# /tmp/ipython-input-3066793616.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='label', y='text_num_words', data=df, palette='Set2')

# %% [markdown]
# The first plot (histogram) shows the overall distribution of caption lengths in terms of word count. Most meme texts contain between 3 to 10 words, forming a right-skewed distribution where very long captions are rare. This confirms that the dataset predominantly consists of short, punchy text segments typical of internet memes.
#
# The second plot (boxplot) compares text length distributions between hateful and non-hateful memes. Both categories share similar median text lengths, but hateful memes display a slightly tighter range and fewer long captions. This suggests that hateful memes tend to rely on short, direct, and emotionally charged phrases, whereas non-hateful memes sometimes include longer, descriptive, or contextual sentences.
#
# Implications:
#
# * The strong skew toward shorter captions means models must focus on semantic meaning rather than text length or verbosity.
#
# * Text length alone is not a strong predictor of hatefulness, but it contributes useful information when combined with linguistic or visual cues.
#
# * The similarity of distributions across classes also reinforces that detecting hatefulness depends more on content and context than on message size.
#
# Key takeaway:
# * The dataset’s textual content is short and concise across both classes, aligning with meme-style communication. While hateful memes are often slightly shorter, textual brevity is a common property of all memes, meaning semantic understanding (via embeddings) is crucial for effective classification.

# %%
# ---------- CELL 5: WORD CLOUDS ----------

# Separate texts by class
text_non_hateful = " ".join(df[df['label'] == 0]['clean_text'])
text_hateful = " ".join(df[df['label'] == 1]['clean_text'])

stopwords = set(STOPWORDS)

# Word cloud for non-hateful memes
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
wc1 = WordCloud(width=600, height=400, stopwords=stopwords, background_color='white', colormap='Greens').generate(text_non_hateful)
plt.imshow(wc1, interpolation='bilinear')
plt.axis('off')
plt.title("Word Cloud — Non-Hateful Memes", fontsize=14)

# Word cloud for hateful memes
plt.subplot(1,2,2)
wc2 = WordCloud(width=600, height=400, stopwords=stopwords, background_color='white', colormap='Reds').generate(text_hateful)
plt.imshow(wc2, interpolation='bilinear')
plt.axis('off')
plt.title("Word Cloud — Hateful Memes", fontsize=14)
plt.show()

# %% [markdown]
# Interpretation : The two word clouds visualize the most frequent words appearing in the captions of non-hateful (left, green) and hateful (right, red) memes.
#
# In the non-hateful memes, the dominant words such as “people,” “love,” “day,” “friend,” “home,” and “happy” reflect positive or neutral sentiment. These words are often used in humorous, motivational, or casual contexts, suggesting inclusive or friendly communication.
#
# In contrast, the hateful memes show more negative or discriminatory language with frequent words like “women,” “kill,” “gay,” “black,” “jew,” “muslim,” and profanity (e.g., “f**”*). These words are associated with identity-based attacks or derogatory remarks, aligning with the dataset’s objective to capture hateful intent.
#
# Key takeaway:
#
# 1. The linguistic contrast between the two classes is clear — non-hateful memes emphasize positivity or general commentary, while hateful memes use targeted or aggressive language.
#
# 2. This validates that text features (word choice, tone, sentiment) are strong indicators for detecting hatefulness and can significantly aid the model in classification.

# %%
# ---------- CELL 6: CORRELATION ----------
corr = df[['label','text_length_chars','text_num_words']].corr()

plt.figure(figsize=(4,3))
sns.heatmap(corr, annot=True, cmap='YlOrRd', fmt=".2f")
plt.title("Correlation Heatmap", fontsize=14)
plt.show()

# %% [markdown]
# The correlation heatmap shows pairwise relationships among three variables — label, text_length_chars, and text_num_words.
#
# * The very high correlation (0.97) between text length in characters and number of words indicates that both features essentially measure the same property (longer texts naturally have more words).
#
# * The correlation of label with text_length_chars (0.11) and text_num_words (0.10) is very weak and positive. This suggests that there is no strong linear relationship between caption length and whether a meme is hateful or not.
#
# Key takeaway:
#
# * While longer captions tend to be slightly more non-hateful, the relationship is weak.
#
# * Therefore, text length alone is not a strong predictor of hatefulness.
#
# * Future modeling should combine linguistic features (like sentiment, keywords, or embeddings) and visual cues from images for better performance.

# %%
# ---------- CELL 7: RANDOM MEME VISUALS ----------
import matplotlib.image as mpimg

# Path to processed images
img_dir = Path("hateful_memes_downsampled/processed_images")

fig, axes = plt.subplots(2, 5, figsize=(15,6))
axes = axes.flatten()

sample_df = df.sample(10, random_state=42).reset_index(drop=True)
for i, ax in enumerate(axes):
    img_path = img_dir / Path(sample_df.loc[i, 'img']).name
    img = mpimg.imread(img_path)
    ax.imshow(img)
    ax.axis('off')
    label = "Hateful" if sample_df.loc[i, 'label'] == 1 else "Non-Hateful"
    ax.set_title(label, fontsize=10)
plt.suptitle("Random Meme Samples (Visual Inspection)", fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# The grid displays a random selection of memes from both the hateful (label 1) and non-hateful (label 0) classes for qualitative visual inspection.
#
# Observations:
#
# * The hateful samples include explicit or implied attacks based on identity, religion, or social groups. Their tone is often sarcastic or derogatory, and the combination of text with suggestive imagery conveys negative sentiment.
#
# * Non-hateful memes, on the other hand, center on humor, everyday life, and awareness topics. They use diverse visuals such as animals, celebrities, or social causes without showing hostility.
#
# Implications:
#
# * Visual and textual cues must be interpreted together to detect hate speech accurately. For instance, some memes may contain neutral text but offensive imagery, or vice-versa.
#
# * This manual inspection highlights the context-dependent nature of hateful content. Simple keyword-based or text-only methods will likely misclassify several memes.
#
# * The dataset therefore provides a challenging and realistic test bed for multimodal learning, where both image and text representations contribute to understanding intent.
#
# Key takeaway:
# * Visual inspection confirms that hateful memes are characterized by short, emotionally charged text paired with contextually harmful imagery, while non-hateful memes exhibit broader themes and neutral tone. Hence, models should rely on both modalities for reliable hate detection.

# %%
# ---------- CELL 8: TEXT-LABEL RELATION ----------
plt.figure(figsize=(6,5))
sns.violinplot(x='label', y='text_length_chars', data=df, palette='cool')
plt.title("Text Length (Characters) vs Label", fontsize=14)
plt.xlabel("Label (0 = Non-Hateful, 1 = Hateful)")
plt.ylabel("Text Length (characters)")
plt.show()
# Out:
# /tmp/ipython-input-2981576595.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='label', y='text_length_chars', data=df, palette='cool')

# %% [markdown]
# The violin plot compares the distribution of text lengths (in characters) across the two meme categories — non-hateful (label 0) and hateful (label 1).
#
# We observe that:
#
# * Both distributions are fairly similar in overall shape, with most captions clustered between 20 and 80 characters.
#
# * However, non-hateful memes (blue) show a slightly wider spread and a few longer captions, while hateful memes (purple) have a denser concentration of shorter texts.
#
# Implication:
#
# * This indicates that hateful memes tend to use short, direct, or provocative phrases, whereas non-hateful memes sometimes include longer, descriptive, or humorous text.
#
# * The difference isn’t extreme, but it aligns with the intuition that hateful content often relies on brevity and emotional impact rather than detailed explanation.
#
# Key takeaway:
# * Caption length can contribute minor discriminative power when combined with other linguistic or visual features, but alone it’s not sufficient to classify a meme’s intent.

# %%
# ---------- CELL 9: SIMPLE TEXT EMBEDDING + t-SNE ----------
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.manifold import TSNE

# Create TF-IDF embeddings
vectorizer = TfidfVectorizer(max_features=500)
X_tfidf = vectorizer.fit_transform(df['clean_text']).toarray()

# Reduce to 2D using t-SNE
tsne = TSNE(n_components=2, random_state=42, perplexity=40, n_iter=500)
X_2d = tsne.fit_transform(X_tfidf)

# Plot t-SNE
plt.figure(figsize=(7,6))
sns.scatterplot(x=X_2d[:,0], y=X_2d[:,1], hue=df['label'], palette='coolwarm', s=30)
plt.title("t-SNE Visualization of TF-IDF Text Embeddings", fontsize=14)
plt.xlabel("Component 1")
plt.ylabel("Component 2")
plt.legend(["Non-Hateful", "Hateful"])
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(

# %% [markdown]
# The t-SNE (t-Distributed Stochastic Neighbor Embedding) plot projects the high-dimensional TF-IDF text embeddings of meme captions into a 2-dimensional space to visually inspect class separability.
#
# * Each point represents a meme:
#
# * Orange → Non-hateful memes
#
# * Blue → Hateful memes
#
# We observe that the points are heavily mixed with some light clustering of similar-colored samples. This means that purely text-based TF-IDF features provide limited separability between hateful and non-hateful memes — many memes with different labels share similar word patterns or vocabulary.
#
# Key insights:
#
# * The overlap suggests that context and visual cues (images) are essential for accurately detecting hateful intent, since textual differences alone are subtle.
#
# * Some small clusters likely represent recurring hate speech phrases or memes with similar wording.
#
# * For improved separability, semantic embeddings (like BERT or CLIP text encoders) could be used instead of basic TF-IDF.
#
# Conclusion:
# The t-SNE plot confirms that textual features contribute useful but incomplete information; multimodal fusion (text + image) is necessary for a robust hateful-meme classifier.

# %%
# ---------- CELL 10: SUMMARY TABLE FOR REPORT ----------
summary_table = {
    "Total Samples": [len(df)],
    "Hateful (1)": [df['label'].sum()],
    "Non-Hateful (0)": [len(df) - df['label'].sum()],
    "Average Words per Meme": [round(df['text_num_words'].mean(), 2)],
    "Median Words per Meme": [round(df['text_num_words'].median(), 2)],
    "Avg Text Length (Chars)": [round(df['text_length_chars'].mean(), 2)]
}

summary_df = pd.DataFrame(summary_table)
print("📊 Dataset Summary:\n")
display(summary_df)
# Out:
# 📊 Dataset Summary:
#    Total Samples  Hateful (1)  Non-Hateful (0)  Average Words per Meme  \
# 0           4000         1435             2565                   11.58
#
#    Median Words per Meme  Avg Text Length (Chars)
# 0                   10.0                    60.11

# %%
# Step 1: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Step 2: Import required libraries
import os
import shutil

# Step 3: Define source and destination paths
source_dir = '/content/hateful_memes_downsampled'  # your current processed folder in Colab VM
drive_save_path = '/content/drive/My Drive/hateful_memes_downsampled'  # path in your Google Drive (My Drive root)

# Step 4: Create destination folder if it doesn't exist
os.makedirs(drive_save_path, exist_ok=True)

# Step 5: Copy entire processed folder and contents to Google Drive
shutil.copytree(source_dir, drive_save_path, dirs_exist_ok=True)

print(f"Dataset saved to Google Drive at: {drive_save_path}")

# Step 6 (optional): Example of saving dataframe directly to Google Drive
# import pandas as pd
# df.to_csv(os.path.join(drive_save_path, 'cleaned_metadata_final.csv'), index=False)
# Out:
# Mounted at /content/drive
# Dataset saved to Google Drive at: /content/drive/My Drive/hateful_memes_downsampled

# %% [markdown]
# # VGG Model

# %%
# VGG feature extraction + RandomForest

#imports
import os, numpy as np, pandas as pd, pickle
from pathlib import Path
from PIL import Image
from tqdm.auto import tqdm

import torch, torch.nn as nn
from torchvision import transforms, models
from torch.utils.data import Dataset, DataLoader

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import accuracy_score, roc_auc_score

#paths
output_dir = Path("hateful_memes_downsampled")
processed_dir = output_dir / "processed_images"
train_csv = output_dir / "train_cleaned.csv"
val_csv   = output_dir / "val_cleaned.csv"
test_csv  = output_dir / "test_cleaned.csv"

#Device selection
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print("Device:", device)

#Image transform--resize/convert to tensor/Normalize with ImageNet means/std because VGG was trained on ImageNet
transform = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.485,0.456,0.406), std=(0.229,0.224,0.225))
])


#This class wraps your CSV so PyTorch DataLoader can iterate images - returns filename so you can map features back to original files if needed.

class SimpleImgDataset(Dataset):
    def __init__(self, df, images_root, transform=None):
        self.df = df.reset_index(drop=True)
        self.root = Path(images_root)
        self.transform = transform
        self.labels = self.df['label'].astype(int).values
        self.fnames = self.df['img'].apply(lambda x: os.path.basename(x)).values
    def __len__(self):
        return len(self.df)
    def __getitem__(self, idx):
        p = self.root / self.fnames[idx]
        img = Image.open(p).convert("RGB")
        if self.transform: img = self.transform(img)
        return img, int(self.labels[idx]), self.fnames[idx]

# load splits
train_df = pd.read_csv(train_csv)
val_df   = pd.read_csv(val_csv)
test_df  = pd.read_csv(test_csv)

train_ds = SimpleImgDataset(train_df, processed_dir, transform=transform)
val_ds   = SimpleImgDataset(val_df,   processed_dir, transform=transform)
test_ds  = SimpleImgDataset(test_df,  processed_dir, transform=transform)

train_loader = DataLoader(train_ds, batch_size=64, shuffle=False, num_workers=2, pin_memory=(device=='cuda'))
val_loader   = DataLoader(val_ds,   batch_size=64, shuffle=False, num_workers=2, pin_memory=(device=='cuda'))
test_loader  = DataLoader(test_ds,  batch_size=64, shuffle=False, num_workers=2, pin_memory=(device=='cuda'))

# load vgg and remove classifier -> we'll use features
try:
    weights = models.VGG16_Weights.IMAGENET1K_V1
    vgg = models.vgg16(weights=weights)
except Exception:
    vgg = models.vgg16(pretrained=True)

vgg = vgg.to(device).eval()
# remove classifier: use features + adaptive pool to get fixed size
feature_extractor = nn.Sequential(
    vgg.features,
    nn.AdaptiveAvgPool2d((7,7))  # VGG original spatial dims, but just to be safe
).to(device)

def extract_features(loader, feat_path):
    all_feats = []
    all_labels = []
    all_names = []
    with torch.no_grad():
        for imgs, labels, fnames in tqdm(loader, desc=f"Extracting to {feat_path.name}"):
            imgs = imgs.to(device)
            feats = feature_extractor(imgs)  # shape (B, C, H, W)
            feats = feats.view(feats.size(0), -1).cpu().numpy()  # (B, C*H*W)
            all_feats.append(feats)
            all_labels.extend(labels)
            all_names.extend(fnames)
    feats_np = np.vstack(all_feats)
    np.save(feat_path, feats_np)
    return feats_np, np.array(all_labels), all_names

# Extract and save features
os.makedirs(output_dir / "vgg_feats", exist_ok=True)
X_train, y_train, _ = extract_features(train_loader, output_dir / "vgg_feats/train_feats.npy")
X_val,   y_val,   _ = extract_features(val_loader,   output_dir / "vgg_feats/val_feats.npy")
X_test,  y_test,  _ = extract_features(test_loader,  output_dir / "vgg_feats/test_feats.npy")

print("Feature shapes:", X_train.shape, X_val.shape, X_test.shape)

# Combine train+val for RF training (if you want)
X_tr_all = np.vstack([X_train, X_val])
y_tr_all = np.concatenate([y_train, y_val])

# Random forest search (similar to your earlier)
from sklearn.model_selection import RandomizedSearchCV
param_dist = {'n_estimators':[50,100,200], 'max_depth':[None,10,30]}
rs = RandomizedSearchCV(RandomForestClassifier(random_state=42), param_dist, n_iter=6, cv=3, scoring='accuracy', n_jobs=-1, verbose=1, random_state=42)
rs.fit(X_tr_all, y_tr_all)
best_rf = rs.best_estimator_
print("Best RF params:", rs.best_params_)

pred = best_rf.predict(X_test)
probs = best_rf.predict_proba(X_test)[:,1]
print("Test acc:", accuracy_score(y_test, pred))
try:
    print("Test AUC:", roc_auc_score(y_test, probs))
except Exception as e:
    print("AUC error:", e)

# save RF
pickle.dump(best_rf, open(output_dir / "vgg_rf_best.pkl","wb"))
np.save(output_dir / "vgg_feats/X_test.npy", X_test)
np.save(output_dir / "vgg_feats/y_test.npy", y_test)
print("Done: features + RF saved.")
# Out:
# Device: cpu
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100%|██████████| 528M/528M [00:07<00:00, 69.9MB/s]
# Extracting to train_feats.npy:   0%|          | 0/50 [00:00<?, ?it/s]
# Extracting to val_feats.npy:   0%|          | 0/7 [00:00<?, ?it/s]
# Extracting to test_feats.npy:   0%|          | 0/7 [00:00<?, ?it/s]
# Feature shapes: (3200, 25088) (400, 25088) (400, 25088)
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# Best RF params: {'n_estimators': 200, 'max_depth': 10}
# Test acc: 0.6475
# Test AUC: 0.5765285298359228
# Done: features + RF saved.

# %% [markdown]
# 1) ROC Curve
# Purpose: overall discrimination ability; AUC summary.
# When: always — single-number and curve for classifier quality.

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
import numpy as np
from pathlib import Path

output_dir = Path("hateful_memes_downsampled/plots"); output_dir.mkdir(parents=True, exist_ok=True)

probs = best_rf.predict_proba(X_test)[:,1]
fpr, tpr, _ = roc_curve(y_test, probs)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr)
plt.plot([0,1],[0,1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'ROC Curve (AUC = {roc_auc:.4f})')
plt.grid(True)
plt.savefig(output_dir / "roc_curve.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# 2) Precision–Recall Curve (test set)
#
# Purpose: better than ROC when classes are imbalanced; shows precision at different recall levels

# %%
from sklearn.metrics import precision_recall_curve, average_precision_score

precision, recall, _ = precision_recall_curve(y_test, probs)
ap = average_precision_score(y_test, probs)

plt.figure()
plt.plot(recall, precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title(f'Precision-Recall Curve (AP = {ap:.4f})')
plt.grid(True)
plt.savefig(output_dir / "pr_curve.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# 3) Confusion Matrix (test set)
#
# Purpose: raw counts of TP/FP/TN/FN — actionable for business decisions (which error matters more).

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

pred = best_rf.predict(X_test)
cm = confusion_matrix(y_test, pred)
disp = ConfusionMatrixDisplay(cm)
plt.figure(figsize=(5,5))
disp.plot(ax=plt.gca())
plt.title('Confusion Matrix (test)')
plt.savefig(output_dir / "confusion_matrix.png", bbox_inches='tight')
plt.show()
