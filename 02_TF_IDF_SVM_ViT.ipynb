# %% [markdown]
# # **# Facebook Hateful Meme Dataset, Downsampling, Preprocessing and EDA.**

# %% [markdown]
# # Starting data file:
# # /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/train.jsonl
# # Preprocessing steps: cleaning, downsampling, text & image normalization

# %%
# Cell 1: Install & import
# !pip install kagglehub --quiet

import os
import shutil
import zipfile
import random
from pathlib import Path
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from tqdm import tqdm

import kagglehub

# %%
# Cell 2: Download dataset with kagglehub
# This will download and return local path where files are stored in the Colab VM
dataset_ref = "parthplc/facebook-hateful-meme-dataset"
path = kagglehub.dataset_download(dataset_ref)
print("Path to dataset files:", path)

# List files in that path to see CSVs and images folder (adjust if path differs)
for root, dirs, files in os.walk(path):
    # print top-level only for brevity
    print(root)
    print("  subdirs:", dirs)
    print("  files (sample):", files[:20])
    break
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/parthplc/facebook-hateful-meme-dataset?dataset_version_number=1...
# 100%|██████████| 3.35G/3.35G [00:47<00:00, 75.2MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1
#   subdirs: ['data']
#   files (sample): []

# %%
#Helper cell before cell 3
import os

for root, dirs, files in os.walk(path):
    for name in files:
        if name.lower().endswith(('.csv', '.json', '.zip', '.tsv', '.xlsx')):
            print(os.path.join(root, name))

# %%
import os

# List all files directly under the downloaded path
print("Files and folders inside:", path)
print(os.listdir(path))
# Out:
# Files and folders inside: /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1
# ['data']

# %%
import os

data_path = os.path.join(path, "data")
print("Files inside data folder:", os.listdir(data_path))

# Also show full paths (in case there are nested subfolders)
for root, dirs, files in os.walk(data_path):
    for name in files:
        print(os.path.join(root, name))
# Out:
# Files inside data folder: ['img', 'LICENSE.txt', 'test.jsonl', 'README.md', 'train.jsonl', 'dev.jsonl']
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/LICENSE.txt
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/test.jsonl
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/README.md
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/train.jsonl
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/dev.jsonl
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/82963.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/89263.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/68934.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/39281.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/48927.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/83901.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/05941.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/32514.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/57619.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/02943.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/74621.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/10234.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/49728.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/56340.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/97256.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/98642.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/89042.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/38460.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/84036.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/84351.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/43612.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/86512.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/07261.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/15630.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/18406.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/04682.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/29416.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/97423.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/58210.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/61092.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/85346.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/50372.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/40563.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/89417.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/79605.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/14873.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/68597.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/83207.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/59408.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/32490.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/16302.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/04716.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/38516.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/37054.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/85392.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/27901.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/68731.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/80591.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/17493.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/06435.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/92341.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/42685.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/18275.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/82169.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/27503.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/71834.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/19536.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/97413.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/81546.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/16075.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/14078.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/43958.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/27613.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/79861.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/17290.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/51734.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/98514.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/10278.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/42160.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/67431.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/52130.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/58674.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/35910.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/97524.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/94067.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/42861.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/17359.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/83456.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/34857.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/35786.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/68721.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/68407.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/20154.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/20957.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/21435.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/65413.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/70254.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/25097.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/70281.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/65092.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/76104.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/37204.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/36781.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/42168.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/86530.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/47159.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/04163.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/64321.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/42510.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/17385.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/04295.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/63052.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/95712.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/30714.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/38217.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/10236.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/28951.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/78306.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/19420.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/63719.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/19047.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/47385.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/01359.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/15427.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/94501.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/76208.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/98016.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/35870.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/49607.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/82765.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/76953.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/96510.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/86032.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/19678.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/45368.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/02384.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/84510.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/45216.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/61580.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/84502.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/42078.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/27548.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/76910.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/63710.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/46721.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/16509.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/12407.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/05976.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/91540.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/94581.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/81705.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/13026.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/70162.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/38641.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/93841.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/03172.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/75146.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/91436.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/17956.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/26043.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/38624.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/98701.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/05689.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/63187.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/74908.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/53241.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/08175.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/68527.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/53096.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/76293.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/62351.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/86023.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/93524.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/90531.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/71492.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/68309.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/10675.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/62308.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/17285.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/16234.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/12754.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/80764.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/35860.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/18274.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/31720.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/97683.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/98374.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/05719.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/90417.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/10827.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/85902.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/28945.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/02165.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/93615.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/71539.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/15394.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/90846.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/85369.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/50482.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/10285.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/10475.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/25416.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/80134.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/85709.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/54692.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/89450.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/72536.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/48203.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/25179.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/78631.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/45031.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/58372.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/73520.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/03685.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/36870.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/32409.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/25816.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/13640.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/36189.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/59346.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/61570.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/34852.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/56280.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/69753.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/16490.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/02764.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/65201.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/46097.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/34726.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/95064.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/24857.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/90386.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/46510.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/05219.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/40193.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/07285.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/24109.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/45379.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/54891.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/13607.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/48703.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/48379.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/51283.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/62175.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/21950.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/05617.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/09283.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/23908.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/74386.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/21403.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/51496.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/27105.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/32410.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/35789.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/09413.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/94780.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/08569.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/04325.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/98124.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/80759.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/96745.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/14652.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/10493.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/13902.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/92817.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/64913.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/76824.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/78302.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/50371.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/01467.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/72431.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/10596.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/05832.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/03642.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/57962.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/64359.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/25806.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/24357.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/34078.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/96420.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/43810.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/69524.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/53624.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/62934.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/14598.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/30871.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/45307.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/97583.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/90573.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/34295.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/87146.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/46739.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/29508.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/91284.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/37860.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/80463.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/32089.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/86123.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/30726.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/98714.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/93081.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/12035.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/97162.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/52614.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/67548.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/71253.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/62081.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/40315.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/32617.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/05476.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/69523.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/07396.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/41907.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/76951.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/02158.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/98346.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/48792.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/43278.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/61038.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/14965.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/52904.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/65183.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/98350.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/72634.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/90214.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/69035.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/12983.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/96250.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/28610.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/65148.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/62457.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/74230.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/13876.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/98134.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/03567.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/53924.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/23940.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/21853.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/64890.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/03874.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/34258.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/38674.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/83756.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/45802.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/81523.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/34056.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/87592.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/89504.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/83740.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/35607.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/15893.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/20718.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/71869.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/45179.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/82590.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/62849.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/27048.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/78925.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/84926.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/32891.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/38427.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/05463.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/56401.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/41376.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/02456.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/37915.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/59021.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/67498.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/83074.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/58190.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/90654.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/64870.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/03178.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/18497.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/05926.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/31048.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/72834.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/80972.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/59462.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/30597.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/03756.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/94180.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/08147.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/90351.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/49201.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/16785.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/56870.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/17405.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/59460.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/53407.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/54719.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/45172.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/87956.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/29173.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/28046.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/40578.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/39542.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/54170.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/06539.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/71432.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/67350.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/16873.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/68371.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/64301.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/36821.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/52613.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/73180.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/15260.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/73049.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/80945.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/57128.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/32650.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/52106.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/39527.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/64935.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/19458.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/54682.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/32015.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/68401.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/35096.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/74390.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/18294.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/87924.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/71398.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/07649.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/70841.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/20681.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/19846.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/83076.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/74038.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/34068.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/53476.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/30847.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/48306.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/59376.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/12694.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/54981.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/60839.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/65273.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/30567.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/10436.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/25768.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/64385.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/87251.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/61840.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/79140.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/96325.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/30489.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/39580.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/94175.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/20751.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/29104.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/25914.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/58209.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/72195.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/58467.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/61732.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/67420.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/03947.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/46902.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/16082.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/82793.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/65149.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/75046.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/42036.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/80932.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/45182.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/29485.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/16280.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/21609.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/39158.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/61802.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/72580.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/08452.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/92806.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/10579.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/47528.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/26495.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/60573.png
# ...
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/07345.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/89067.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/82591.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/97542.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/53108.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/54179.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/85947.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/37058.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/54367.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/67058.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/87526.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/76148.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/49136.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/09248.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/48905.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/51304.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/80436.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/91863.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/61205.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/19385.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/46527.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/57284.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/28059.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/90516.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/34092.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/01765.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/84021.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/53628.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/51602.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/02185.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/48250.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/39250.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/94230.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/29756.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/71658.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/67435.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/51369.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/03145.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/83704.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/19823.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/10835.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/61793.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/62340.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/68512.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/34628.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/23164.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/81265.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/42351.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/61538.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/68417.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/70415.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/59743.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/79138.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/86059.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/03267.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/14082.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/60142.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/89750.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/84362.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/48269.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/09423.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/27398.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/15306.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/97325.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/54210.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/71628.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/84172.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/41672.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/06842.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/27603.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/24157.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/73680.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/16702.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/24579.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/93826.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/29614.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/85912.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/85960.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/26085.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/94571.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/18935.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/06412.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/97514.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/37546.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/05734.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/53618.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/85761.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/87934.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/68507.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/46270.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/46283.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/93087.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/39425.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/12589.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/72406.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/60549.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/09285.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/37284.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/13652.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/47326.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/76510.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/19526.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/45382.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/53694.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/19834.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/03185.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/17023.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/93261.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/56723.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/31694.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/45698.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/46918.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/63250.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/17645.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/10829.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/46509.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/45806.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/68517.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/84069.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/21637.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/52801.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/15409.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/02947.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/16047.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/67352.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/05798.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/80924.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/10985.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/79162.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/62814.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/71583.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/85743.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/26189.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/25197.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/79531.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/09215.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/61257.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/52609.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/96280.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/18307.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/05846.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/64907.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/35017.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/60483.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/38701.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/84709.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/98023.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/53806.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/80231.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/60439.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/20879.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/36805.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/31284.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/53980.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/09468.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/81069.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/70329.png
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/img/56081.png

# %%
import os

data_path = os.path.join(path, "data")

# Look only for json/jsonl/csv files (ignore images)
meta_files = []
for root, dirs, files in os.walk(data_path):
    for name in files:
        if name.lower().endswith(('.json', '.jsonl', '.csv', '.tsv')):
            meta_files.append(os.path.join(root, name))

print("Metadata files found:")
for f in meta_files:
    print(f)
# Out:
# Metadata files found:
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/test.jsonl
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/train.jsonl
# /root/.cache/kagglehub/datasets/parthplc/facebook-hateful-meme-dataset/versions/1/data/dev.jsonl

# %%
#data/
 #├── img/             ← meme images
 #├── train.jsonl      ← training metadata
 #├── dev.jsonl        ← validation metadata
 #└── test.jsonl       ← test metadata

# %%
#Load the training data
import pandas as pd

train_path = os.path.join(path, "data", "train.jsonl")

# Load JSON lines file
df = pd.read_json(train_path, lines=True)
print("✅ Loaded train.jsonl successfully")
print("Shape:", df.shape)
print("\nColumns:", df.columns.tolist())

# Display first few rows
df.head()
# Out:
# ✅ Loaded train.jsonl successfully
# Shape: (8500, 4)
#
# Columns: ['id', 'img', 'label', 'text']
#       id            img  label  \
# 0  42953  img/42953.png      0
# 1  23058  img/23058.png      0
# 2  13894  img/13894.png      0
# 3  37408  img/37408.png      0
# 4  82403  img/82403.png      0
#
#                                                 text
# 0   its their character not their color that matters
# 1  don't be afraid to love again everyone is not ...
# 2                           putting bows on your pet
# 3  i love everything and everybody! except for sq...
# 4  everybody loves chocolate chip cookies, even h...

# %%
#Check Class Distribution
print("Class distribution:")
print(df['label'].value_counts())

# Percentage split
print("\nPercentage split:")
print((df['label'].value_counts(normalize=True) * 100).round(2))
# Out:
# Class distribution:
# label
# 0    5450
# 1    3050
# Name: count, dtype: int64
#
# Percentage split:
# label
# 0    64.12
# 1    35.88
# Name: proportion, dtype: float64

# %% [markdown]
#  Dataset size: 8,500 memes
#
#  Columns: id, img, label, text
#
#  Class distribution:
#
# Non-hateful (0): 64%
#
# Hateful (1): 36%
#
# Images stored under: data/img/

# %% [markdown]
# ## **DownSampling of the Data**

# %%
#Downsampling of the dataset
from sklearn.model_selection import train_test_split
import os
from pathlib import Path
import shutil
from tqdm import tqdm

# Parameters
downsample_n = 4000          # change to another size later if needed
random_state = 42

# Calculate fraction
frac = downsample_n / len(df)

# Stratified sampling based on 'label'
idx = df.index.values
idx_sample, _ = train_test_split(
    idx,
    train_size=frac,
    stratify=df['label'],
    random_state=random_state
)

df_sample = df.loc[idx_sample].reset_index(drop=True)

print("Downsampled shape:", df_sample.shape)
print("Label distribution in sample:")
print(df_sample['label'].value_counts(normalize=True).round(3) * 100)

# Create output folders
output_dir = Path("hateful_memes_downsampled")
images_out = output_dir / "images"
os.makedirs(images_out, exist_ok=True)

# Paths
image_base_dir = os.path.join(path, "data")

# Copy images
print("\nCopying selected images...")
for img_file in tqdm(df_sample['img']):
    src = os.path.join(image_base_dir, img_file)
    dst = os.path.join(images_out, os.path.basename(img_file))
    shutil.copy(src, dst)

# Save downsampled CSV
df_sample.to_csv(output_dir / "downsampled_metadata.csv", index=False)
print("\n✅ Downsample complete.")
print("Saved to:", output_dir / "downsampled_metadata.csv")
print("Images saved in:", images_out)
# Out:
# Downsampled shape: (4000, 4)
# Label distribution in sample:
# label
# 0    64.1
# 1    35.9
# Name: proportion, dtype: float64
#
# Copying selected images...
# 100%|██████████| 4000/4000 [00:06<00:00, 600.17it/s]
# ✅ Downsample complete.
# Saved to: hateful_memes_downsampled/downsampled_metadata.csv
# Images saved in: hateful_memes_downsampled/images

# %%
len(os.listdir("hateful_memes_downsampled/images"))
# Out:
# 4000

# %% [markdown]
# # **Preprocessing of the Data**

# %%
# ---------- CELL A: imports + helpers ----------
# !pip install tqdm --quiet

import os, re, string, shutil, json
from pathlib import Path
from tqdm import tqdm
import pandas as pd
import numpy as np
import cv2
from sklearn.model_selection import train_test_split

# reproducibility
RND = 42

# helper: robust text cleaner (removes emojis, urls, punctuation, numbers)
def clean_text_advanced(text):
    text = "" if pd.isna(text) else str(text)
    # lowercase
    text = text.lower()
    # remove urls
    text = re.sub(r"http\S+|www\S+|https\S+", "", text, flags=re.IGNORECASE)
    # remove emojis (simple approach)
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags
                               "]+", flags=re.UNICODE)
    text = emoji_pattern.sub(r"", text)
    # remove digits
    text = re.sub(r"\d+", "", text)
    # remove punctuation
    text = re.sub(f"[{re.escape(string.punctuation)}]", "", text)
    # normalize whitespace
    text = re.sub(r"\s+", " ", text).strip()
    return text

# %%
# ---------- CELL B: ensure df_sample available ----------
# If df_sample already exists in environment (from previous steps), this is no-op.
if 'df_sample' in globals():
    print("df_sample already present with shape:", df_sample.shape)
else:
    # try reloading train.jsonl and re-create sample (safe fallback)
    dataset_jsonl = Path(path) / "data" / "train.jsonl"
    if dataset_jsonl.exists():
        print("Loading full train.jsonl from:", dataset_jsonl)
        df_full = pd.read_json(dataset_jsonl, lines=True)
        print("Full df shape:", df_full.shape)
        # if you want to re-create the same 4000-sample downsample, use same seed
        downsample_n = 4000
        idx = df_full.index.values
        frac = downsample_n / len(df_full)
        idx_sample, _ = train_test_split(idx, train_size=frac, stratify=df_full['label'], random_state=RND)
        df_sample = df_full.loc[idx_sample].reset_index(drop=True)
        print("Recreated df_sample shape:", df_sample.shape)
    else:
        raise FileNotFoundError("df_sample not found and train.jsonl not present at expected location. Make sure you have path and dataset downloaded.")
# Out:
# df_sample already present with shape: (4000, 4)

# %%
# ---------- CELL C: sanity checks ----------
output_dir = Path("hateful_memes_downsampled")
images_dir = output_dir / "images"                     # images you copied earlier
processed_dir = output_dir / "processed_images"       # later output

print("df_sample shape:", df_sample.shape)
print("\nColumns:", df_sample.columns.tolist())

# Ensure label ints
df_sample['label'] = df_sample['label'].astype(int)

# Check duplicates (image filename + text)
dup_img = df_sample.duplicated(subset=['img']).sum()
dup_text = df_sample.duplicated(subset=['text']).sum()
print(f"\nDuplicate image filenames: {dup_img}")
print(f"Duplicate text entries: {dup_text}")

# Check missing files in images_dir
missing_files = []
for img in df_sample['img']:
    fname = os.path.basename(img)
    if not (images_dir / fname).exists():
        missing_files.append(fname)
print(f"\nMissing image files in {images_dir}: {len(missing_files)}")
if len(missing_files)>0:
    print("First 20 missing:", missing_files[:20])

# Quick drop of any rows that point to missing images (if any)
if len(missing_files) > 0:
    before = len(df_sample)
    df_sample = df_sample[~df_sample['img'].apply(lambda x: os.path.basename(x) in set(missing_files))].reset_index(drop=True)
    print(f"Dropped {before - len(df_sample)} rows due to missing images. New shape: {df_sample.shape}")

# Drop exact duplicates if present (very rare)
before = len(df_sample)
df_sample.drop_duplicates(subset=['img','text'], inplace=True)
print("Dropped exact duplicates:", before - len(df_sample))
# Out:
# df_sample shape: (4000, 4)
#
# Columns: ['id', 'img', 'label', 'text']
#
# Duplicate image filenames: 0
# Duplicate text entries: 389
#
# Missing image files in hateful_memes_downsampled/images: 0
# Dropped exact duplicates: 0

# %%
# ---------- CELL D: text cleaning & derived features ----------
# Apply the advanced cleaning function
tqdm.pandas(desc="Cleaning text")
df_sample['clean_text'] = df_sample['text'].progress_apply(clean_text_advanced)

# Derived features helpful for EDA
df_sample['text_length_chars'] = df_sample['clean_text'].apply(len)
df_sample['text_num_words'] = df_sample['clean_text'].apply(lambda x: len(x.split()) if x else 0)

# Quick stats
print("After cleaning: sample shape:", df_sample.shape)
print("\nText length (chars) — descriptive stats:")
print(df_sample['text_length_chars'].describe().round(2))
print("\nText num words — descriptive stats:")
print(df_sample['text_num_words'].describe().round(2))
# Out:
# Cleaning text: 100%|██████████| 4000/4000 [00:00<00:00, 19993.85it/s]
# After cleaning: sample shape: (4000, 7)
#
# Text length (chars) — descriptive stats:
# count    4000.00
# mean       60.11
# std        36.18
# min         4.00
# 25%        36.00
# 50%        52.00
# 75%        75.00
# max       427.00
# Name: text_length_chars, dtype: float64
#
# Text num words — descriptive stats:
# count    4000.00
# mean       11.58
# std         6.80
# min         1.00
# 25%         7.00
# 50%        10.00
# 75%        15.00
# max        68.00
# Name: text_num_words, dtype: float64

# %%
# ---------- CELL E: image preprocessing (resize + normalize) ----------
# Settings
target_size = (224, 224)
os.makedirs(processed_dir, exist_ok=True)

corrupted = []
copied = 0

for idx, row in tqdm(df_sample.iterrows(), total=len(df_sample), desc="Process images"):
    img_rel = row['img']
    img_name = os.path.basename(img_rel)
    src_path = images_dir / img_name
    dst_path = processed_dir / img_name

    try:
        img = cv2.imread(str(src_path))
        if img is None:
            corrupted.append(img_name)
            continue

        # If image channels are 1 or 4 handle them
        # convert grayscale to BGR if needed
        if len(img.shape) == 2:
            img = cv2.cvtColor(img, cv2.COLOR_GRAY2BGR)
        # drop alpha channel if present
        if img.shape[2] == 4:
            img = cv2.cvtColor(img, cv2.COLOR_BGRA2BGR)

        # resize
        img_resized = cv2.resize(img, target_size, interpolation=cv2.INTER_AREA)

        # normalize (0-255 saving still as uint8; later model pipelines typically scale to 0-1)
        cv2.imwrite(str(dst_path), img_resized)
        copied += 1
    except Exception as e:
        corrupted.append(img_name)

print(f"\nImages processed: {copied}; Corrupted/unreadable: {len(corrupted)}")
if len(corrupted)>0:
    print("First 20 corrupted:", corrupted[:20])
    # drop corrupted rows from df_sample
    before = len(df_sample)
    df_sample = df_sample[~df_sample['img'].apply(lambda x: os.path.basename(x) in set(corrupted))].reset_index(drop=True)
    print(f"Dropped {before - len(df_sample)} rows with corrupted images. New shape: {df_sample.shape}")
# Out:
# Process images: 100%|██████████| 4000/4000 [01:42<00:00, 39.05it/s]
# Images processed: 4000; Corrupted/unreadable: 0

# %%
# ---------- CELL F: save cleaned metadata + zip processed images ----------
clean_meta_path = output_dir / "cleaned_metadata_final.csv"
df_sample.to_csv(clean_meta_path, index=False)
print("Saved cleaned metadata to:", clean_meta_path)

# Zip processed images (optional, may take some time and disk)
zip_out = output_dir / "processed_images.zip"
if zip_out.exists():
    print("Zip already exists:", zip_out)
else:
    print("Creating zip (this may take a while)...")
    shutil.make_archive(str(zip_out).replace('.zip',''), 'zip', processed_dir)
    print("Created zip:", zip_out)

# Quick checks
print("\nFinal cleaned dataset shape:", df_sample.shape)
print("Processed image count:", len(list(processed_dir.glob("*.*"))))
# Out:
# Saved cleaned metadata to: hateful_memes_downsampled/cleaned_metadata_final.csv
# Creating zip (this may take a while)...
# Created zip: hateful_memes_downsampled/processed_images.zip
#
# Final cleaned dataset shape: (4000, 7)
# Processed image count: 4000

# %%
# ---------- CELL G: create stratified train/val/test splits ----------
train_val, test_df = train_test_split(df_sample, test_size=0.10, stratify=df_sample['label'], random_state=RND)
train_df, val_df = train_test_split(train_val, test_size=0.1111111, stratify=train_val['label'], random_state=RND)
# note: 0.1111111 of train_val => ~10% overall val (since 0.9 * 0.111... = 0.1)

print("Train shape:", train_df.shape)
print("Val shape:", val_df.shape)
print("Test shape:", test_df.shape)

# Save
train_df.to_csv(output_dir / "train_cleaned.csv", index=False)
val_df.to_csv(output_dir / "val_cleaned.csv", index=False)
test_df.to_csv(output_dir / "test_cleaned.csv", index=False)
print("Saved splits to:", output_dir)
# Out:
# Train shape: (3200, 7)
# Val shape: (400, 7)
# Test shape: (400, 7)
# Saved splits to: hateful_memes_downsampled

# %% [markdown]
# Here we are doing binary classification (Hateful vs Non-Hateful).That is why we are using Stratified sampling because it ensures:
#
# 1. Each split represents both types of memes fairly,
#
# 2. Our model learns from both classes, and
#
# 3. Evaluation metrics reflect the true behavior.
#
# That’s why we chose stratify=df['label'] for both:
#
# Downsampling step, and
#
# Train/validation/test split step.

# %%
# ---------- CELL H: quick EDA checks ----------
print("Overall class distribution (final):")
print(df_sample['label'].value_counts(), "\n")
print("Percentages:")
print((df_sample['label'].value_counts(normalize=True) * 100).round(2))

# Text length distributions
print("\nText length (words) mean / median:")
print(df_sample['text_num_words'].mean(), df_sample['text_num_words'].median())

# Example rows
display(df_sample.sample(6))
# Out:
# Overall class distribution (final):
# label
# 0    2565
# 1    1435
# Name: count, dtype: int64
#
# Percentages:
# label
# 0    64.12
# 1    35.88
# Name: proportion, dtype: float64
#
# Text length (words) mean / median:
# 11.576 10.0
#          id            img  label  \
# 2838  28613  img/28613.png      1
# 2853  10935  img/10935.png      0
# 1545  98501  img/98501.png      0
# 1594  83271  img/83271.png      1
# 1897  14968  img/14968.png      1
# 0     78925  img/78925.png      1
#
#                                                    text  \
# 2838  if slavery had cellphones on the plantation li...
# 2853                              modern japanese '' ''
# 1545                                   send me sexy pic
# 1594  having a bad day? you could be a siamese twin ...
# 1897              iroc z italian retards out 'cruising'
# 0     trans rights? the only trans i support is the ...
#
#                                              clean_text  text_length_chars  \
# 2838  if slavery had cellphones on the plantation li...                 60
# 2853                                    modern japanese                 15
# 1545                                   send me sexy pic                 16
# 1594  having a bad day you could be a siamese twin a...                117
# 1897                iroc z italian retards out cruising                 35
# 0     trans rights the only trans i support is the t...                 70
#
#       text_num_words
# 2838              10
# 2853               2
# 1545               4
# 1594              26
# 1897               6
# 0                 12

# %% [markdown]
# # **EDA (Exploratory Data Analysis) of the Data**

# %%
# ---------- CELL 1: IMPORTS & LOAD CLEANED DATA ----------

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud, STOPWORDS
import cv2
import numpy as np
import random
from PIL import Image
from pathlib import Path

# Load cleaned dataset (from preprocessing step)
df = pd.read_csv("hateful_memes_downsampled/cleaned_metadata_final.csv")

print("✅ Dataset loaded successfully.")
print("Shape:", df.shape)
print("\nColumns:", df.columns.tolist())
print("\nSample rows:")
display(df.sample(5))
# Out:
# ✅ Dataset loaded successfully.
# Shape: (4000, 7)
#
# Columns: ['id', 'img', 'label', 'text', 'clean_text', 'text_length_chars', 'text_num_words']
#
# Sample rows:
#          id            img  label  \
# 2895  60254  img/60254.png      0
# 1907  80153  img/80153.png      0
# 691   30192  img/30192.png      1
# 1427  52640  img/52640.png      1
# 515   38259  img/38259.png      0
#
#                                                    text  \
# 2895  the best thing you can do is find a person who...
# 1907  i love it when people think my posts are about...
# 691   when tr*nnies want to be accepted but they mut...
# 1427    luckily she's so fat or it never would have fit
# 515   when the mexican lady at taco bell messes up y...
#
#                                              clean_text  text_length_chars  \
# 2895  the best thing you can do is find a person who...                204
# 1907  i love it when people think my posts are about...                111
# 691   when trnnies want to be accepted but they muti...                 63
# 1427     luckily shes so fat or it never would have fit                 46
# 515   when the mexican lady at taco bell messes up y...                 55
#
#       text_num_words
# 2895              42
# 1907              22
# 691               11
# 1427              10
# 515               11

# %%
# ---------- CELL 2: BASIC INFO ----------

print("Dataset Info:\n")
print(df.info())
print("\n\nMissing Values per Column:")
print(df.isnull().sum())

print("\n\nLabel Distribution:")
print(df['label'].value_counts())

print("\nPercentage Split:")
print((df['label'].value_counts(normalize=True) * 100).round(2))
# Out:
# Dataset Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 4000 non-null   int64
#  1   img                4000 non-null   object
#  2   label              4000 non-null   int64
#  3   text               4000 non-null   object
#  4   clean_text         4000 non-null   object
#  5   text_length_chars  4000 non-null   int64
#  6   text_num_words     4000 non-null   int64
# dtypes: int64(4), object(3)
# memory usage: 218.9+ KB
# None
#
#
# Missing Values per Column:
# id                   0
# img                  0
# label                0
# text                 0
# clean_text           0
# text_length_chars    0
# text_num_words       0
# dtype: int64
#
#
# Label Distribution:
# label
# 0    2565
# 1    1435
# Name: count, dtype: int64
#
# Percentage Split:
# label
# 0    64.12
# 1    35.88
# Name: proportion, dtype: float64

# %%
# ---------- CELL 3: CLASS DISTRIBUTION PLOT ----------
plt.figure(figsize=(6,4))
sns.countplot(x='label', data=df, palette='coolwarm')
plt.title("Class Distribution of Memes", fontsize=14)
plt.xlabel("Label (0 = Non-Hateful, 1 = Hateful)")
plt.ylabel("Count")
plt.show()
# Out:
# /tmp/ipython-input-97431609.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='label', data=df, palette='coolwarm')

# %% [markdown]
# The bar chart displays the number of hateful (label = 1) and non-hateful (label = 0) memes in the dataset. It reveals that approximately 64 % of the samples are non-hateful and 36 % are hateful, resulting in a moderately imbalanced dataset.
#
# Observations:
#
# * The higher number of non-hateful memes means models may naturally learn to favor the majority class unless corrective measures are taken.
#
# * Despite the imbalance not being extreme, it can still bias predictions toward “non-hateful” outputs.
#
# Implications:
#
# * Stratified sampling (as you already used) ensures this ratio is preserved in train, validation, and test splits.
#
# * During model training, techniques like class-weighted loss functions or oversampling of the minority class can help mitigate bias.
#
# Key takeaway:
# * The dataset is moderately imbalanced (roughly 64 : 36). Awareness of this imbalance is essential for fair model evaluation and to prevent the classifier from under-detecting hateful content.

# %%
# ---------- CELL 4: TEXT LENGTH ANALYSIS ----------

plt.figure(figsize=(7,5))
sns.histplot(df['text_num_words'], bins=30, kde=True, color='teal')
plt.title("Distribution of Text Length (in Words)", fontsize=14)
plt.xlabel("Number of Words")
plt.ylabel("Frequency")
plt.show()

# Compare text length per class
plt.figure(figsize=(7,5))
sns.boxplot(x='label', y='text_num_words', data=df, palette='Set2')
plt.title("Text Length Distribution per Class", fontsize=14)
plt.xlabel("Label (0 = Non-Hateful, 1 = Hateful)")
plt.ylabel("Number of Words")
plt.show()
# Out:
# /tmp/ipython-input-3066793616.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='label', y='text_num_words', data=df, palette='Set2')

# %% [markdown]
# The first plot (histogram) shows the overall distribution of caption lengths in terms of word count. Most meme texts contain between 3 to 10 words, forming a right-skewed distribution where very long captions are rare. This confirms that the dataset predominantly consists of short, punchy text segments typical of internet memes.
#
# The second plot (boxplot) compares text length distributions between hateful and non-hateful memes. Both categories share similar median text lengths, but hateful memes display a slightly tighter range and fewer long captions. This suggests that hateful memes tend to rely on short, direct, and emotionally charged phrases, whereas non-hateful memes sometimes include longer, descriptive, or contextual sentences.
#
# Implications:
#
# * The strong skew toward shorter captions means models must focus on semantic meaning rather than text length or verbosity.
#
# * Text length alone is not a strong predictor of hatefulness, but it contributes useful information when combined with linguistic or visual cues.
#
# * The similarity of distributions across classes also reinforces that detecting hatefulness depends more on content and context than on message size.
#
# Key takeaway:
# * The dataset’s textual content is short and concise across both classes, aligning with meme-style communication. While hateful memes are often slightly shorter, textual brevity is a common property of all memes, meaning semantic understanding (via embeddings) is crucial for effective classification.

# %%
# ---------- CELL 5: WORD CLOUDS ----------

# Separate texts by class
text_non_hateful = " ".join(df[df['label'] == 0]['clean_text'])
text_hateful = " ".join(df[df['label'] == 1]['clean_text'])

stopwords = set(STOPWORDS)

# Word cloud for non-hateful memes
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
wc1 = WordCloud(width=600, height=400, stopwords=stopwords, background_color='white', colormap='Greens').generate(text_non_hateful)
plt.imshow(wc1, interpolation='bilinear')
plt.axis('off')
plt.title("Word Cloud — Non-Hateful Memes", fontsize=14)

# Word cloud for hateful memes
plt.subplot(1,2,2)
wc2 = WordCloud(width=600, height=400, stopwords=stopwords, background_color='white', colormap='Reds').generate(text_hateful)
plt.imshow(wc2, interpolation='bilinear')
plt.axis('off')
plt.title("Word Cloud — Hateful Memes", fontsize=14)
plt.show()

# %% [markdown]
# Interpretation : The two word clouds visualize the most frequent words appearing in the captions of non-hateful (left, green) and hateful (right, red) memes.
#
# In the non-hateful memes, the dominant words such as “people,” “love,” “day,” “friend,” “home,” and “happy” reflect positive or neutral sentiment. These words are often used in humorous, motivational, or casual contexts, suggesting inclusive or friendly communication.
#
# In contrast, the hateful memes show more negative or discriminatory language with frequent words like “women,” “kill,” “gay,” “black,” “jew,” “muslim,” and profanity (e.g., “f**”*). These words are associated with identity-based attacks or derogatory remarks, aligning with the dataset’s objective to capture hateful intent.
#
# Key takeaway:
#
# 1. The linguistic contrast between the two classes is clear — non-hateful memes emphasize positivity or general commentary, while hateful memes use targeted or aggressive language.
#
# 2. This validates that text features (word choice, tone, sentiment) are strong indicators for detecting hatefulness and can significantly aid the model in classification.

# %%
# ---------- CELL 6: CORRELATION ----------
corr = df[['label','text_length_chars','text_num_words']].corr()

plt.figure(figsize=(4,3))
sns.heatmap(corr, annot=True, cmap='YlOrRd', fmt=".2f")
plt.title("Correlation Heatmap", fontsize=14)
plt.show()

# %% [markdown]
# The correlation heatmap shows pairwise relationships among three variables — label, text_length_chars, and text_num_words.
#
# * The very high correlation (0.97) between text length in characters and number of words indicates that both features essentially measure the same property (longer texts naturally have more words).
#
# * The correlation of label with text_length_chars (0.11) and text_num_words (0.10) is very weak and positive. This suggests that there is no strong linear relationship between caption length and whether a meme is hateful or not.
#
# Key takeaway:
#
# * While longer captions tend to be slightly more non-hateful, the relationship is weak.
#
# * Therefore, text length alone is not a strong predictor of hatefulness.
#
# * Future modeling should combine linguistic features (like sentiment, keywords, or embeddings) and visual cues from images for better performance.

# %%
# ---------- CELL 7: RANDOM MEME VISUALS ----------
import matplotlib.image as mpimg

# Path to processed images
img_dir = Path("hateful_memes_downsampled/processed_images")

fig, axes = plt.subplots(2, 5, figsize=(15,6))
axes = axes.flatten()

sample_df = df.sample(10, random_state=42).reset_index(drop=True)
for i, ax in enumerate(axes):
    img_path = img_dir / Path(sample_df.loc[i, 'img']).name
    img = mpimg.imread(img_path)
    ax.imshow(img)
    ax.axis('off')
    label = "Hateful" if sample_df.loc[i, 'label'] == 1 else "Non-Hateful"
    ax.set_title(label, fontsize=10)
plt.suptitle("Random Meme Samples (Visual Inspection)", fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# The grid displays a random selection of memes from both the hateful (label 1) and non-hateful (label 0) classes for qualitative visual inspection.
#
# Observations:
#
# * The hateful samples include explicit or implied attacks based on identity, religion, or social groups. Their tone is often sarcastic or derogatory, and the combination of text with suggestive imagery conveys negative sentiment.
#
# * Non-hateful memes, on the other hand, center on humor, everyday life, and awareness topics. They use diverse visuals such as animals, celebrities, or social causes without showing hostility.
#
# Implications:
#
# * Visual and textual cues must be interpreted together to detect hate speech accurately. For instance, some memes may contain neutral text but offensive imagery, or vice-versa.
#
# * This manual inspection highlights the context-dependent nature of hateful content. Simple keyword-based or text-only methods will likely misclassify several memes.
#
# * The dataset therefore provides a challenging and realistic test bed for multimodal learning, where both image and text representations contribute to understanding intent.
#
# Key takeaway:
# * Visual inspection confirms that hateful memes are characterized by short, emotionally charged text paired with contextually harmful imagery, while non-hateful memes exhibit broader themes and neutral tone. Hence, models should rely on both modalities for reliable hate detection.

# %%
# ---------- CELL 8: TEXT-LABEL RELATION ----------
plt.figure(figsize=(6,5))
sns.violinplot(x='label', y='text_length_chars', data=df, palette='cool')
plt.title("Text Length (Characters) vs Label", fontsize=14)
plt.xlabel("Label (0 = Non-Hateful, 1 = Hateful)")
plt.ylabel("Text Length (characters)")
plt.show()
# Out:
# /tmp/ipython-input-2981576595.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='label', y='text_length_chars', data=df, palette='cool')

# %% [markdown]
# The violin plot compares the distribution of text lengths (in characters) across the two meme categories — non-hateful (label 0) and hateful (label 1).
#
# We observe that:
#
# * Both distributions are fairly similar in overall shape, with most captions clustered between 20 and 80 characters.
#
# * However, non-hateful memes (blue) show a slightly wider spread and a few longer captions, while hateful memes (purple) have a denser concentration of shorter texts.
#
# Implication:
#
# * This indicates that hateful memes tend to use short, direct, or provocative phrases, whereas non-hateful memes sometimes include longer, descriptive, or humorous text.
#
# * The difference isn’t extreme, but it aligns with the intuition that hateful content often relies on brevity and emotional impact rather than detailed explanation.
#
# Key takeaway:
# * Caption length can contribute minor discriminative power when combined with other linguistic or visual features, but alone it’s not sufficient to classify a meme’s intent.

# %%
# ---------- CELL 9: SIMPLE TEXT EMBEDDING + t-SNE ----------
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.manifold import TSNE

# Create TF-IDF embeddings
vectorizer = TfidfVectorizer(max_features=500)
X_tfidf = vectorizer.fit_transform(df['clean_text']).toarray()

# Reduce to 2D using t-SNE
tsne = TSNE(n_components=2, random_state=42, perplexity=40, n_iter=500)
X_2d = tsne.fit_transform(X_tfidf)

# Plot t-SNE
plt.figure(figsize=(7,6))
sns.scatterplot(x=X_2d[:,0], y=X_2d[:,1], hue=df['label'], palette='coolwarm', s=30)
plt.title("t-SNE Visualization of TF-IDF Text Embeddings", fontsize=14)
plt.xlabel("Component 1")
plt.ylabel("Component 2")
plt.legend(["Non-Hateful", "Hateful"])
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(

# %% [markdown]
# The t-SNE (t-Distributed Stochastic Neighbor Embedding) plot projects the high-dimensional TF-IDF text embeddings of meme captions into a 2-dimensional space to visually inspect class separability.
#
# * Each point represents a meme:
#
# * Orange → Non-hateful memes
#
# * Blue → Hateful memes
#
# We observe that the points are heavily mixed with some light clustering of similar-colored samples. This means that purely text-based TF-IDF features provide limited separability between hateful and non-hateful memes — many memes with different labels share similar word patterns or vocabulary.
#
# Key insights:
#
# * The overlap suggests that context and visual cues (images) are essential for accurately detecting hateful intent, since textual differences alone are subtle.
#
# * Some small clusters likely represent recurring hate speech phrases or memes with similar wording.
#
# * For improved separability, semantic embeddings (like BERT or CLIP text encoders) could be used instead of basic TF-IDF.
#
# Conclusion:
# The t-SNE plot confirms that textual features contribute useful but incomplete information; multimodal fusion (text + image) is necessary for a robust hateful-meme classifier.

# %%
# ---------- CELL 10: SUMMARY TABLE FOR REPORT ----------
summary_table = {
    "Total Samples": [len(df)],
    "Hateful (1)": [df['label'].sum()],
    "Non-Hateful (0)": [len(df) - df['label'].sum()],
    "Average Words per Meme": [round(df['text_num_words'].mean(), 2)],
    "Median Words per Meme": [round(df['text_num_words'].median(), 2)],
    "Avg Text Length (Chars)": [round(df['text_length_chars'].mean(), 2)]
}

summary_df = pd.DataFrame(summary_table)
print("📊 Dataset Summary:\n")
display(summary_df)
# Out:
# 📊 Dataset Summary:
#    Total Samples  Hateful (1)  Non-Hateful (0)  Average Words per Meme  \
# 0           4000         1435             2565                   11.58
#
#    Median Words per Meme  Avg Text Length (Chars)
# 0                   10.0                    60.11

# %%
# Step 1: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Step 2: Import required libraries
import os
import shutil

# Step 3: Define source and destination paths
source_dir = '/content/hateful_memes_downsampled'  # your current processed folder in Colab VM
drive_save_path = '/content/drive/My Drive/hateful_memes_downsampled'  # path in your Google Drive (My Drive root)

# Step 4: Create destination folder if it doesn't exist
os.makedirs(drive_save_path, exist_ok=True)

# Step 5: Copy entire processed folder and contents to Google Drive
shutil.copytree(source_dir, drive_save_path, dirs_exist_ok=True)

print(f"Dataset saved to Google Drive at: {drive_save_path}")

# Step 6 (optional): Example of saving dataframe directly to Google Drive
# import pandas as pd
# df.to_csv(os.path.join(drive_save_path, 'cleaned_metadata_final.csv'), index=False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1264016456.py in <cell line: 0>()
#      15
#      16 # Step 5: Copy entire processed folder and contents to Google Drive
# ---> 17 shutil.copytree(source_dir, drive_save_path, dirs_exist_ok=True)
#      18
#      19 print(f"Dataset saved to Google Drive at: {drive_save_path}")
#
# /usr/lib/python3.12/shutil.py in copytree(src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks, dirs_exist_ok)
#     598     with os.scandir(src) as itr:
#     599         entries = list(itr)
# --> 600     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#     601                      ignore=ignore, copy_function=copy_function,
#     602                      ignore_dangling_symlinks=ignore_dangling_symlinks,
#
# /usr/lib/python3.12/shutil.py in _copytree(entries, src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks, dirs_exist_ok)
#     534                         copy_function(srcobj, dstname)
#     535             elif srcentry.is_dir():
# --> 536                 copytree(srcobj, dstname, symlinks, ignore, copy_function,
#     537                          ignore_dangling_symlinks, dirs_exist_ok)
#     538             else:
#
# /usr/lib/python3.12/shutil.py in copytree(src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks, dirs_exist_ok)
#     598     with os.scandir(src) as itr:
#     599         entries = list(itr)
# --> 600     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#     601                      ignore=ignore, copy_function=copy_function,
#     602                      ignore_dangling_symlinks=ignore_dangling_symlinks,
#
# /usr/lib/python3.12/shutil.py in _copytree(entries, src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks, dirs_exist_ok)
#     538             else:
#     539                 # Will raise a SpecialFileError for unsupported file types
# --> 540                 copy_function(srcobj, dstname)
#     541         # catch the Error from the recursive copytree so that we can
#     542         # continue with other files
#
# /usr/lib/python3.12/shutil.py in copy2(src, dst, follow_symlinks)
#     473                 raise
#     474
# --> 475     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     476     copystat(src, dst, follow_symlinks=follow_symlinks)
#     477     return dst
#
# /usr/lib/python3.12/shutil.py in copyfile(src, dst, follow_symlinks)
#     260         with open(src, 'rb') as fsrc:
#     261             try:
# --> 262                 with open(dst, 'wb') as fdst:
#     263                     # macOS
#     264                     if _HAS_FCOPYFILE:
#
# KeyboardInterrupt:

# %% [markdown]
# TF-IDF + SVM  (text)

# %%
# !pip install -q sentence-transformers timm transformers

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os, pickle, numpy as np, pandas as pd
from sklearn.model_selection import train_test_split, StratifiedKFold, RandomizedSearchCV, GridSearchCV, learning_curve
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, roc_curve, auc
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sentence_transformers import SentenceTransformer
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import timm
from torchvision import transforms, models
from PIL import Image
from tqdm import tqdm

# %%
DATA_CSV = "/content/drive/My Drive/hateful_memes_downsampled/cleaned_metadata_final.csv"
IMG_BASE_PATH = "/content/drive/My Drive/hateful_memes_downsampled/processed_images/"

# %%
# 2) Load data
df = pd.read_csv(DATA_CSV)
df['img'] = IMG_BASE_PATH + df['img'].str.replace('img/','', regex=False)
df = df[['img','clean_text','label']].dropna().reset_index(drop=True)
print("Total rows:", len(df))
display(df.head())
# Out:
# Total rows: 4000
#                                                  img  \
# 0  /content/drive/My Drive/hateful_memes_downsamp...
# 1  /content/drive/My Drive/hateful_memes_downsamp...
# 2  /content/drive/My Drive/hateful_memes_downsamp...
# 3  /content/drive/My Drive/hateful_memes_downsamp...
# 4  /content/drive/My Drive/hateful_memes_downsamp...
#
#                                           clean_text  label
# 0  trans rights the only trans i support is the t...      1
# 1  people were killed at christchurch muslim peop...      1
# 2                     felt cute might pray later idk      0
# 3   black people anything that doesnt belong to them      1
# 4          members of the white supremacist movement      0

# %%
# 3) Split once (everyone must reuse same splits)
RANDOM_STATE = 42
train_idx, temp_idx = train_test_split(df.index, test_size=0.30, random_state=RANDOM_STATE, stratify=df['label'])
val_idx, test_idx = train_test_split(temp_idx, test_size=0.50, random_state=RANDOM_STATE, stratify=df.loc[temp_idx,'label'])
df_train = df.loc[train_idx].reset_index(drop=True)
df_val   = df.loc[val_idx].reset_index(drop=True)
df_test  = df.loc[test_idx].reset_index(drop=True)
y_train, y_val, y_test = df_train['label'].values, df_val['label'].values, df_test['label'].values
print(len(df_train), len(df_val), len(df_test))
# Out:
# 2800 600 600

# %%
# Utility functions
def metrics(y_true,y_pred,y_score=None):
    res = {
        'accuracy': accuracy_score(y_true,y_pred),
        'precision': precision_score(y_true,y_pred, zero_division=0),
        'recall': recall_score(y_true,y_pred, zero_division=0),
        'f1': f1_score(y_true,y_pred, zero_division=0),
        'auc': roc_auc_score(y_true,y_score) if y_score is not None else None
    }
    return res

# %%
def plot_conf(y_true,y_pred,title):
    cm = confusion_matrix(y_true,y_pred)
    sns.heatmap(cm, annot=True, fmt='d'); plt.title(title); plt.xlabel("Pred"); plt.ylabel("True"); plt.show()

# %%
def plot_roc(y_true,y_score,title):
    fpr,tpr,_=roc_curve(y_true,y_score)
    print("AUC:", auc(fpr,tpr))
    plt.plot(fpr,tpr); plt.plot([0,1],[0,1],"--",color="gray"); plt.title(title); plt.xlabel("FPR"); plt.ylabel("TPR"); plt.show()

# %%
def plot_learning(estimator, X, y, title):
    train_sizes, train_scores, val_scores = learning_curve(estimator, X, y, cv=5, scoring='accuracy', train_sizes=np.linspace(0.1,1.0,5), n_jobs=-1)
    plt.plot(train_sizes, train_scores.mean(axis=1), label='train'); plt.plot(train_sizes, val_scores.mean(axis=1), label='val')
    plt.fill_between(train_sizes, train_scores.mean(axis=1)-train_scores.std(axis=1), train_scores.mean(axis=1)+train_scores.std(axis=1), alpha=0.1)
    plt.fill_between(train_sizes, val_scores.mean(axis=1)-val_scores.std(axis=1), val_scores.mean(axis=1)+val_scores.std(axis=1), alpha=0.1)
    plt.title(title); plt.xlabel("Training examples"); plt.ylabel("Accuracy"); plt.legend(); plt.show()

# %%
# Easy model: TF-IDF + SVM
# -------------------------
tfidf = TfidfVectorizer(max_features=5000, ngram_range=(1,2))
X_tr_tfidf = tfidf.fit_transform(df_train['clean_text'].astype(str))
X_val_tfidf = tfidf.transform(df_val['clean_text'].astype(str))
X_test_tfidf = tfidf.transform(df_test['clean_text'].astype(str))

# Grid search for linear SVM C
pipe = Pipeline([('scaler', StandardScaler(with_mean=False)), ('svm', SVC(kernel='linear', probability=True))])
param_grid = {'svm__C':[0.01,0.1,1,10]}
gs = GridSearchCV(pipe, param_grid, cv=3, scoring='accuracy', n_jobs=-1, verbose=1)
gs.fit(X_tr_tfidf, y_train)
print("Best SVM params:", gs.best_params_)
best_svm = gs.best_estimator_
pred = best_svm.predict(X_test_tfidf); probs = best_svm.predict_proba(X_test_tfidf)[:,1]
print("TFIDF+SVM metrics:", metrics(y_test,pred,probs))
plot_conf(y_test,pred,"TF-IDF + SVM Confusion Matrix")
plot_roc(y_test,probs,"TF-IDF + SVM ROC")
plot_learning(best_svm, X_tr_tfidf, y_train, "Learning curve: TF-IDF + SVM")
# Out:
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# Best SVM params: {'svm__C': 0.01}
# TFIDF+SVM metrics: {'accuracy': 0.5716666666666667, 'precision': 0.40454545454545454, 'recall': 0.413953488372093, 'f1': 0.4091954022988506, 'auc': np.float64(0.5746602234974328)}
# AUC: 0.5746602234974328

# %%
# Save
import pickle
pickle.dump(best_svm, open("member1_svm_best.pkl","wb"))

# %% [markdown]
# # Hard model: ViT (feature-extraction + RF)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
vit = timm.create_model("vit_base_patch16_224", pretrained=True)
vit.reset_classifier(0)
vit = vit.to(device).eval()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5, 0.5, 0.5),
                         std=(0.5, 0.5, 0.5))
])

# %% [markdown]
# # Feature Extraction Function

# %%
def extract_vit_feats(paths):
    feats = []
    with torch.no_grad():
        for p in tqdm(paths):
            img = Image.open(p).convert("RGB")
            x = transform(img).unsqueeze(0).to(device)

            # Works for all timm versions:
            if hasattr(vit, "forward_features"):
                f = vit.forward_features(x)  # Extract embeddings before classification head
            else:
                f = vit(x)  # fallback if forward_features not found

            feats.append(f.cpu().numpy().reshape(-1))
    return np.vstack(feats)

# %%
X_tr_vit = extract_vit_feats(df_train['img'].tolist())
X_test_vit = extract_vit_feats(df_test['img'].tolist())
# Out:
# 100%|██████████| 2800/2800 [41:50<00:00,  1.12it/s]
# 100%|██████████| 600/600 [08:52<00:00,  1.13it/s]

# %%
from sklearn.ensemble import RandomForestClassifier
param_dist = {'n_estimators':[50,100,200], 'max_depth':[None,10,30]}
rs = RandomizedSearchCV(RandomForestClassifier(random_state=42), param_dist, n_iter=6, cv=3, scoring='accuracy', n_jobs=-1, verbose=1, random_state=42)
rs.fit(X_tr_vit, y_train)
best_rf = rs.best_estimator_
pred = best_rf.predict(X_test_vit); probs = best_rf.predict_proba(X_test_vit)[:,1]
print("ViT-feats+RF metrics:", metrics(y_test,pred,probs))
plot_conf(y_test,pred,"ViT-feat + RF Confusion Matrix")
plot_roc(y_test,probs,"ViT-feat + RF ROC")
plot_learning(best_rf, X_tr_vit, y_train, "Learning curve: ViT-features + RF")

pickle.dump(best_rf, open("member1_vit_rf_best.pkl","wb"))

# Loss function equations for report:
print("Binary Cross-Entropy (Logistic) Loss: L = -[y log p + (1-y) log(1-p)]")
# Out:
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# ViT-feats+RF metrics: {'accuracy': 0.635, 'precision': 0.3333333333333333, 'recall': 0.018604651162790697, 'f1': 0.03524229074889868, 'auc': np.float64(0.5658230141951073)}
# AUC: 0.5658230141951073
# Binary Cross-Entropy (Logistic) Loss: L = -[y log p + (1-y) log(1-p)]
